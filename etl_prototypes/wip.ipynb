# %% [markdown]
# Connected to venv_nadlan_311 (Python 3.11.13)

# %%
print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
#
# NameError: name 'dates_range' is not defined

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables

# %%
path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
dates_range = ("01/01/2026", "01/03/2026")

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending
# Out:
#                                                     0          1  \
# 0                                        יתרה בחשבון:   29856.69
# 1                                        מסגרת אשראי:   20000.00
# 2                                      תנועות אחרונות        NaN
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
#                          2               3         4          5         6  \
# 0                 לתאריך -  05/03/26 23:15       NaN        NaN       NaN
# 1                      NaN             NaN       NaN        NaN       NaN
# 2                      NaN             NaN       NaN        NaN       NaN
# 3                סוג תנועה            זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)             NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)             NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)             NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)             NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)             NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)         3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)          112.00       NaN     338.93     13104
# 11              ריבית עו"ש           13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)         3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)         5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)             NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)             NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)             NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)         4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)             NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)          115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)         5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)         5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)             NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)        17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)        20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)             NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)             NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)             NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)          946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)             NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)             NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)             NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)          115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)          219.00       NaN   30216.69     63051
# 36                     NaN             NaN       NaN        NaN       NaN
# 37                     NaN             NaN       NaN        NaN       NaN
#
#               __source_file  \
# 0   AccountActivity (1).xls
# 1   AccountActivity (1).xls
# 2   AccountActivity (1).xls
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
#                                         __source_path __source_ext  \
# 0   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 32  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 33  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 34  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 35  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 36  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 37  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                  __source_rule
# 0   mizrachi_read_html_table_1
# 1   mizrachi_read_html_table_1
# 2   mizrachi_read_html_table_1
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1
# 32  mizrachi_read_html_table_1
# 33  mizrachi_read_html_table_1
# 34  mizrachi_read_html_table_1
# 35  mizrachi_read_html_table_1
# 36  mizrachi_read_html_table_1
# 37  mizrachi_read_html_table_1

# %%
    columns_numbers = range(len(df_pending.columns))
    for column_number in columns_numbers:
        temp_column = df_pending.columns[column_number]
        first_row_detected = 3 # default to 3 rows in this case
        if df_pending.iloc[0, temp_column].isna():
            print(f"Header row detected in column {column_number}")
            first_row_detected = df_pending[temp_column].isna().sum()
            break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       3 temp_column = df_pending.columns[column_number]
#       4 first_row_detected = 3 # default to 3 rows in this case
# ----> 5 if df_pending.iloc[0, temp_column].isna():
#       6     print(f"Header row detected in column {column_number}")
#       7     first_row_detected = df_pending[temp_column].isna().sum()
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:968, in _LocationIndexer._validate_tuple_indexer(self, key)
#     966         self._validate_key(k, i)
#     967     except ValueError as err:
# --> 968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#     972 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
columns_numbers = range(len(df_pending.columns))

# %%
columns_numbers
# Out:
# range(0, 11)

# %%
column_number = 4

# %%
temp_column = df_pending.columns[column_number]

# %%
temp_column
# Out:
# '4'

# %%
df_pending.iloc[0, temp_column].isna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_pending.iloc[0, temp_column].isna()
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexing.py:968, in _LocationIndexer._validate_tuple_indexer(self, key)
#     966         self._validate_key(k, i)
#     967     except ValueError as err:
# --> 968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#     972 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
df_pending.iloc[0, column_number]
# Out:
# nan

# %%
df_pending.iloc[0, column_number].isna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_pending.iloc[0, column_number].isna()
#
# AttributeError: 'float' object has no attribute 'isna'

# %%
df_pending.iloc[0, column_number]
# Out:
# nan

# %%
df_pending.iloc[0, column_number].isna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_pending.iloc[0, column_number].isna()
#
# AttributeError: 'float' object has no attribute 'isna'

# %%
df_pending.iloc[0, column_number].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_pending.iloc[0, column_number].isnull()
#
# AttributeError: 'float' object has no attribute 'isnull'

# %%
import pandas as pd

# %%
pd.isnull(df_pending.iloc[0, column_number])
# Out:
# True

# %%
df_pending[temp_column].isna()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20     True
# 21     True
# 22     True
# 23    False
# 24     True
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# Name: 4, dtype: bool

# %%
df_pending[temp_column].isna().sum()
# Out:
# np.int64(19)

# %%
df_pending[temp_column].notna()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26     True
# 27     True
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# Name: 4, dtype: bool

# %%
df_pending[temp_column].notna().head(0)
# Out:
# Series([], Name: 4, dtype: bool)

# %%
df_pending[temp_column].notna().head(1)
# Out:
# 0    False
# Name: 4, dtype: bool

# %%
df_pending[temp_column].notna().head(0).env.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_57940\931709815.py in ?()
# ----> 1 df_pending[temp_column].notna().head(0).env.index
#
# c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'env'

# %%
df_pending[temp_column].notna().head(0).index
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
df_pending[temp_column].notna()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26     True
# 27     True
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# Name: 4, dtype: bool

# %%
df_pending[temp_column].notna()[df_pending[temp_column].notna()]
# Out:
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 14    True
# 15    True
# 16    True
# 17    True
# 19    True
# 23    True
# 26    True
# 27    True
# 28    True
# 29    True
# 31    True
# 32    True
# 33    True
# Name: 4, dtype: bool

# %%
df_pending[temp_column].notna()[df_pending[temp_column].notna()].index
# Out:
# Index([3, 4, 5, 6, 7, 8, 14, 15, 16, 17, 19, 23, 26, 27, 28, 29, 31, 32, 33], dtype='int64')

# %%
df_pending[temp_column].notna()[df_pending[temp_column].notna()].index[0]
# Out:
# np.int64(3)

# %%
df = df_pending

# %%
df
# Out:
#                                                     0          1  \
# 0                                        יתרה בחשבון:   29856.69
# 1                                        מסגרת אשראי:   20000.00
# 2                                      תנועות אחרונות        NaN
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
#                          2               3         4          5         6  \
# 0                 לתאריך -  05/03/26 23:15       NaN        NaN       NaN
# 1                      NaN             NaN       NaN        NaN       NaN
# 2                      NaN             NaN       NaN        NaN       NaN
# 3                סוג תנועה            זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)             NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)             NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)             NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)             NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)             NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)         3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)          112.00       NaN     338.93     13104
# 11              ריבית עו"ש           13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)         3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)         5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)             NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)             NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)             NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)         4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)             NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)          115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)         5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)         5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)             NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)        17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)        20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)             NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)             NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)             NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)          946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)             NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)             NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)             NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)          115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)          219.00       NaN   30216.69     63051
# 36                     NaN             NaN       NaN        NaN       NaN
# 37                     NaN             NaN       NaN        NaN       NaN
#
#               __source_file  \
# 0   AccountActivity (1).xls
# 1   AccountActivity (1).xls
# 2   AccountActivity (1).xls
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
#                                         __source_path __source_ext  \
# 0   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 32  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 33  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 34  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 35  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 36  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 37  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                  __source_rule
# 0   mizrachi_read_html_table_1
# 1   mizrachi_read_html_table_1
# 2   mizrachi_read_html_table_1
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1
# 32  mizrachi_read_html_table_1
# 33  mizrachi_read_html_table_1
# 34  mizrachi_read_html_table_1
# 35  mizrachi_read_html_table_1
# 36  mizrachi_read_html_table_1
# 37  mizrachi_read_html_table_1

# %%
df[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df[2]
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 2

# %%
df['2']
# Out:
# 0                   לתאריך -
# 1                        NaN
# 2                        NaN
# 3                  סוג תנועה
# 4        ביצוע הוראת קבע (י)
# 5          הרשאה ישראכרט (י)
# 6     מור גמל ופנסיה בע"מ(י)
# 7           טן חברה לדלק (י)
# 8     הרשאה מקס איט פיננס(י)
# 9     זיכוי - בנק הפועלים(י)
# 10    ב. לאומי- קיצבת ילד(י)
# 11                ריבית עו"ש
# 12    זיכוי - בנק הפועלים(י)
# 13    זיכוי - בנק הפועלים(י)
# 14       ביצוע הוראת קבע (י)
# 15         הרשאה ישראכרט (י)
# 16          טן חברה לדלק (י)
# 17    מור גמל ופנסיה בע"מ(י)
# 18    זיכוי - בנק הפועלים(י)
# 19    הרשאה מקס איט פיננס(י)
# 20    ב. לאומי- קיצבת ילד(י)
# 21    זיכוי - בנק הפועלים(י)
# 22    זיכוי - בנק הפועלים(י)
# 23    הרשאה מקס איט פיננס(י)
# 24    זיכוי - בנק הפועלים(י)
# 25    ביטוח לאומי חד פעמי(י)
# 26       ביצוע הוראת קבע (י)
# 27         הרשאה ישראכרט (י)
# 28    הרשאה מקס איט פיננס(י)
# 29    מור גמל ופנסיה בע"מ(י)
# 30    ביטוח לאומי חד פעמי(י)
# 31        העברה באינטרנט (י)
# 32    הרשאה מקס איט פיננס(י)
# 33        העברה באינטרנט (י)
# 34    ב. לאומי- קיצבת ילד(י)
# 35    ביטוח לאומי חד פעמי(י)
# 36                       NaN
# 37                       NaN
# Name: 2, dtype: object

# %%
df['2'].iloc[0:1]
# Out:
# 0    לתאריך -
# Name: 2, dtype: object

# %%
df['3'].iloc[0:1]
# Out:
# 0    05/03/26 23:15
# Name: 3, dtype: object

# %%
df['4'].iloc[0:1]
# Out:
# 0    NaN
# Name: 4, dtype: object

# %%
df['4'].iloc[0:1].isna()
# Out:
# 0    True
# Name: 4, dtype: bool

# %%
df['4'].iloc[0:1].isna().any()
# Out:
# np.True_

# %%
probe_rows: int = 1

# %%
candidate_cols = [
    col for col in df.columns
    if df[col].iloc[:probe_rows].isna().any()
]

# %%
candidate_cols
# Out:
# ['4', '5', '6']

# %%
df[candidate_cols]
# Out:
#            4          5         6
# 0        NaN        NaN       NaN
# 1        NaN        NaN       NaN
# 2        NaN        NaN       NaN
# 3       חובה  יתרה בש"ח    אסמכתא
# 4     600.00    9451.53        29
# 5    2874.04        NaN     20543
# 6    1000.00    5577.49     57318
# 7     481.84    5095.65     27839
# 8    7868.72   -2773.07     34685
# 9        NaN     226.93     99012
# 10       NaN     338.93     13104
# 11       NaN     352.65  55555555
# 12       NaN        NaN     99012
# 13       NaN    8552.65     99012
# 14    600.00        NaN        29
# 15   2504.63        NaN     20543
# 16    476.61        NaN     27839
# 17    800.00    4171.41     57318
# 18       NaN    9161.41     99012
# 19   5875.55    3285.86     34685
# 20       NaN    3400.86     13104
# 21       NaN    8400.86     99012
# 22       NaN   13400.86     99012
# 23     62.78   13338.08     34685
# 24       NaN   30338.08     99012
# 25       NaN        NaN     63051
# 26    600.00        NaN        29
# 27   3427.00        NaN     20543
# 28    500.00        NaN     34685
# 29    800.00   45326.08     57318
# 30       NaN        NaN     63051
# 31   2000.00   44272.08      6715
# 32  12989.39        NaN     34685
# 33   1400.00   29882.69     25643
# 34       NaN   29997.69     13104
# 35       NaN   30216.69     63051
# 36       NaN        NaN       NaN
# 37       NaN        NaN       NaN

# %%
df[candidate_cols[0]]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3         חובה
# 4       600.00
# 5      2874.04
# 6      1000.00
# 7       481.84
# 8      7868.72
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14      600.00
# 15     2504.63
# 16      476.61
# 17      800.00
# 18         NaN
# 19     5875.55
# 20         NaN
# 21         NaN
# 22         NaN
# 23       62.78
# 24         NaN
# 25         NaN
# 26      600.00
# 27     3427.00
# 28      500.00
# 29      800.00
# 30         NaN
# 31     2000.00
# 32    12989.39
# 33     1400.00
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# Name: 4, dtype: object

# %%
df[candidate_cols[0]].find_valid_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_57940\2131697406.py in ?()
# ----> 1 df[candidate_cols[0]].find_valid_index()
#
# c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'find_valid_index'

# %%
df[candidate_cols[0]].first_valid_index()
# Out:
# 3

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
import pandas as pd


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Header row detection
# I want to detect a column that it's first row is NAN, that is a good enough signautre to detect header row.
first_row_detected = detect_header_row_mizrachi_case(df_pending)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
first_row_detected
# Out:
# 3

# %%
df_pending = df_pending.iloc[first_row_detected:]

# %%
df_pending
# Out:
#                                                     0          1  \
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
#                          2         3         4          5         6  \
# 3                סוג תנועה      זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)       NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)       NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)       NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)       NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)       NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)   3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)    112.00       NaN     338.93     13104
# 11              ריבית עו"ש     13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)   3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)   5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)       NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)       NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)       NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)       NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)   4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)       NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)    115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)   5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)   5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)       NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)  17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)  20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)       NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)       NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)       NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)       NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)    946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)       NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)       NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)       NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)    115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)    219.00       NaN   30216.69     63051
# 36                     NaN       NaN       NaN        NaN       NaN
# 37                     NaN       NaN       NaN        NaN       NaN
#
#               __source_file  \
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
#                                         __source_path __source_ext  \
# 3   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 32  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 33  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 34  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 35  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 36  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 37  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                  __source_rule
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1
# 32  mizrachi_read_html_table_1
# 33  mizrachi_read_html_table_1
# 34  mizrachi_read_html_table_1
# 35  mizrachi_read_html_table_1
# 36  mizrachi_read_html_table_1
# 37  mizrachi_read_html_table_1

# %%
df
# Out:
#                                                     0          1  \
# 0                                        יתרה בחשבון:   29856.69
# 1                                        מסגרת אשראי:   20000.00
# 2                                      תנועות אחרונות        NaN
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
#                          2               3         4          5         6  \
# 0                 לתאריך -  05/03/26 23:15       NaN        NaN       NaN
# 1                      NaN             NaN       NaN        NaN       NaN
# 2                      NaN             NaN       NaN        NaN       NaN
# 3                סוג תנועה            זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)             NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)             NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)             NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)             NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)             NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)         3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)          112.00       NaN     338.93     13104
# 11              ריבית עו"ש           13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)         3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)         5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)             NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)             NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)             NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)         4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)             NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)          115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)         5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)         5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)             NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)        17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)        20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)             NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)             NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)             NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)          946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)             NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)             NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)             NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)          115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)          219.00       NaN   30216.69     63051
# 36                     NaN             NaN       NaN        NaN       NaN
# 37                     NaN             NaN       NaN        NaN       NaN
#
#               __source_file  \
# 0   AccountActivity (1).xls
# 1   AccountActivity (1).xls
# 2   AccountActivity (1).xls
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
#                                         __source_path __source_ext  \
# 0   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 32  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 33  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 34  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 35  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 36  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 37  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                  __source_rule
# 0   mizrachi_read_html_table_1
# 1   mizrachi_read_html_table_1
# 2   mizrachi_read_html_table_1
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1
# 32  mizrachi_read_html_table_1
# 33  mizrachi_read_html_table_1
# 34  mizrachi_read_html_table_1
# 35  mizrachi_read_html_table_1
# 36  mizrachi_read_html_table_1
# 37  mizrachi_read_html_table_1

# %%
df['3']
# Out:
# 0     05/03/26 23:15
# 1                NaN
# 2                NaN
# 3               זכות
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9            3000.00
# 10            112.00
# 11             13.72
# 12           3200.00
# 13           5000.00
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18           4990.00
# 19               NaN
# 20            115.00
# 21           5000.00
# 22           5000.00
# 23               NaN
# 24          17000.00
# 25          20315.00
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# 30            946.00
# 31               NaN
# 32               NaN
# 33               NaN
# 34            115.00
# 35            219.00
# 36               NaN
# 37               NaN
# Name: 3, dtype: object

# %%
df['4']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3         חובה
# 4       600.00
# 5      2874.04
# 6      1000.00
# 7       481.84
# 8      7868.72
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14      600.00
# 15     2504.63
# 16      476.61
# 17      800.00
# 18         NaN
# 19     5875.55
# 20         NaN
# 21         NaN
# 22         NaN
# 23       62.78
# 24         NaN
# 25         NaN
# 26      600.00
# 27     3427.00
# 28      500.00
# 29      800.00
# 30         NaN
# 31     2000.00
# 32    12989.39
# 33     1400.00
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# Name: 4, dtype: object

# %%
df['4'].first_valid_index()
# Out:
# 3

# %%
df.loc[3:]
# Out:
#                                                     0          1  \
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
#                          2         3         4          5         6  \
# 3                סוג תנועה      זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)       NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)       NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)       NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)       NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)       NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)   3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)    112.00       NaN     338.93     13104
# 11              ריבית עו"ש     13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)   3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)   5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)       NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)       NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)       NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)       NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)   4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)       NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)    115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)   5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)   5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)       NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)  17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)  20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)       NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)       NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)       NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)       NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)    946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)       NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)       NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)       NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)    115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)    219.00       NaN   30216.69     63051
# 36                     NaN       NaN       NaN        NaN       NaN
# 37                     NaN       NaN       NaN        NaN       NaN
#
#               __source_file  \
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
#                                         __source_path __source_ext  \
# 3   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 32  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 33  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 34  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 35  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 36  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 37  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                  __source_rule
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1
# 32  mizrachi_read_html_table_1
# 33  mizrachi_read_html_table_1
# 34  mizrachi_read_html_table_1
# 35  mizrachi_read_html_table_1
# 36  mizrachi_read_html_table_1
# 37  mizrachi_read_html_table_1

# %%
df.loc[4:]
# Out:
#                                                     0    1  \
# 4                                            10/12/25  NaN
# 5                                            10/12/25  NaN
# 6                                            10/12/25  NaN
# 7                                            11/12/25  NaN
# 8                                            15/12/25  NaN
# 9                                            16/12/25  NaN
# 10                                           21/12/25  NaN
# 11                                           01/01/26  NaN
# 12                                           04/01/26  NaN
# 13                                           04/01/26  NaN
# 14                                           11/01/26  NaN
# 15                                           11/01/26  NaN
# 16                                           11/01/26  NaN
# 17                                           11/01/26  NaN
# 18                                           12/01/26  NaN
# 19                                           15/01/26  NaN
# 20                                           20/01/26  NaN
# 21                                           01/02/26  NaN
# 22                                           04/02/26  NaN
# 23                                           06/02/26  NaN
# 24                                           08/02/26  NaN
# 25                                           10/02/26  NaN
# 26                                           10/02/26  NaN
# 27                                           10/02/26  NaN
# 28                                           10/02/26  NaN
# 29                                           10/02/26  NaN
# 30                                           13/02/26  NaN
# 31                                           13/02/26  NaN
# 32                                           15/02/26  NaN
# 33                                           15/02/26  NaN
# 34                                           20/02/26  NaN
# 35                                           25/02/26  NaN
# 36                                        תנועות היום  NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...  NaN
#
#                          2         3         4         5         6  \
# 4      ביצוע הוראת קבע (י)       NaN    600.00   9451.53        29
# 5        הרשאה ישראכרט (י)       NaN   2874.04       NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)       NaN   1000.00   5577.49     57318
# 7         טן חברה לדלק (י)       NaN    481.84   5095.65     27839
# 8   הרשאה מקס איט פיננס(י)       NaN   7868.72  -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)   3000.00       NaN    226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)    112.00       NaN    338.93     13104
# 11              ריבית עו"ש     13.72       NaN    352.65  55555555
# 12  זיכוי - בנק הפועלים(י)   3200.00       NaN       NaN     99012
# 13  זיכוי - בנק הפועלים(י)   5000.00       NaN   8552.65     99012
# 14     ביצוע הוראת קבע (י)       NaN    600.00       NaN        29
# 15       הרשאה ישראכרט (י)       NaN   2504.63       NaN     20543
# 16        טן חברה לדלק (י)       NaN    476.61       NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)       NaN    800.00   4171.41     57318
# 18  זיכוי - בנק הפועלים(י)   4990.00       NaN   9161.41     99012
# 19  הרשאה מקס איט פיננס(י)       NaN   5875.55   3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)    115.00       NaN   3400.86     13104
# 21  זיכוי - בנק הפועלים(י)   5000.00       NaN   8400.86     99012
# 22  זיכוי - בנק הפועלים(י)   5000.00       NaN  13400.86     99012
# 23  הרשאה מקס איט פיננס(י)       NaN     62.78  13338.08     34685
# 24  זיכוי - בנק הפועלים(י)  17000.00       NaN  30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)  20315.00       NaN       NaN     63051
# 26     ביצוע הוראת קבע (י)       NaN    600.00       NaN        29
# 27       הרשאה ישראכרט (י)       NaN   3427.00       NaN     20543
# 28  הרשאה מקס איט פיננס(י)       NaN    500.00       NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)       NaN    800.00  45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)    946.00       NaN       NaN     63051
# 31      העברה באינטרנט (י)       NaN   2000.00  44272.08      6715
# 32  הרשאה מקס איט פיננס(י)       NaN  12989.39       NaN     34685
# 33      העברה באינטרנט (י)       NaN   1400.00  29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)    115.00       NaN  29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)    219.00       NaN  30216.69     63051
# 36                     NaN       NaN       NaN       NaN       NaN
# 37                     NaN       NaN       NaN       NaN       NaN
#
#               __source_file  \
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
#                                         __source_path __source_ext  \
# 4   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...         .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 32  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 33  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 34  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 35  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 36  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 37  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                  __source_rule
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1
# 32  mizrachi_read_html_table_1
# 33  mizrachi_read_html_table_1
# 34  mizrachi_read_html_table_1
# 35  mizrachi_read_html_table_1
# 36  mizrachi_read_html_table_1
# 37  mizrachi_read_html_table_1

# %%
df.iloc[first_row_detected:first_row_detected+1]
# Out:
#        0          1          2     3     4          5       6  \
# 3  תאריך  תאריך ערך  סוג תנועה  זכות  חובה  יתרה בש"ח  אסמכתא
#
#              __source_file                                      __source_path  \
# 3  AccountActivity (1).xls  C:\Users\shai\Documents\personal\personal_proj...
#
#   __source_ext               __source_rule
# 3         .xls  mizrachi_read_html_table_1

# %%
df.iloc[first_row_detected+2:first_row_detected+2]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5, 6, __source_file, __source_path, __source_ext, __source_rule]
# Index: []

# %%
df.iloc[first_row_detected:first_row_detected]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5, 6, __source_file, __source_path, __source_ext, __source_rule]
# Index: []

# %%
df.iloc[first_row_detected:first_row_detected+1]
# Out:
#        0          1          2     3     4          5       6  \
# 3  תאריך  תאריך ערך  סוג תנועה  זכות  חובה  יתרה בש"ח  אסמכתא
#
#              __source_file                                      __source_path  \
# 3  AccountActivity (1).xls  C:\Users\shai\Documents\personal\personal_proj...
#
#   __source_ext               __source_rule
# 3         .xls  mizrachi_read_html_table_1

# %%
df.iloc[first_row_detected:first_row_detected+1].values
# Out:
# array([['תאריך', 'תאריך ערך', 'סוג תנועה', 'זכות', 'חובה', 'יתרה בש"ח',
#         'אסמכתא', 'AccountActivity (1).xls',
#         'C:\\Users\\shai\\Documents\\personal\\personal_projects\\ynab-israel-consolidator\\private_data\\incoming\\bank_mizrachi\\AccountActivity (1).xls',
#         '.xls', 'mizrachi_read_html_table_1']], dtype=object)

# %%
df.iloc[first_row_detected:first_row_detected+1,:]
# Out:
#        0          1          2     3     4          5       6  \
# 3  תאריך  תאריך ערך  סוג תנועה  זכות  חובה  יתרה בש"ח  אסמכתא
#
#              __source_file                                      __source_path  \
# 3  AccountActivity (1).xls  C:\Users\shai\Documents\personal\personal_proj...
#
#   __source_ext               __source_rule
# 3         .xls  mizrachi_read_html_table_1

# %%
df.iloc[first_row_detected:first_row_detected+1,:].values
# Out:
# array([['תאריך', 'תאריך ערך', 'סוג תנועה', 'זכות', 'חובה', 'יתרה בש"ח',
#         'אסמכתא', 'AccountActivity (1).xls',
#         'C:\\Users\\shai\\Documents\\personal\\personal_projects\\ynab-israel-consolidator\\private_data\\incoming\\bank_mizrachi\\AccountActivity (1).xls',
#         '.xls', 'mizrachi_read_html_table_1']], dtype=object)

# %%
df.iloc[first_row_detected:first_row_detected+1,:].values[0]
# Out:
# array(['תאריך', 'תאריך ערך', 'סוג תנועה', 'זכות', 'חובה', 'יתרה בש"ח',
#        'אסמכתא', 'AccountActivity (1).xls',
#        'C:\\Users\\shai\\Documents\\personal\\personal_projects\\ynab-israel-consolidator\\private_data\\incoming\\bank_mizrachi\\AccountActivity (1).xls',
#        '.xls', 'mizrachi_read_html_table_1'], dtype=object)

# %%
header_row_idx = detect_header_row_mizrachi_case(df_pending)

# %%
df_pending.iloc[header_row_idx, :]
# Out:
# 0                                                         10/12/25
# 1                                                              NaN
# 2                                           מור גמל ופנסיה בע"מ(י)
# 3                                                              NaN
# 4                                                          1000.00
# 5                                                          5577.49
# 6                                                            57318
# __source_file                              AccountActivity (1).xls
# __source_path    C:\Users\shai\Documents\personal\personal_proj...
# __source_ext                                                  .xls
# __source_rule                           mizrachi_read_html_table_1
# Name: 6, dtype: object

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Header row detection
# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)
df_pending.columns = df_pending.iloc[header_row_idx, :]
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending.iloc[header_row_idx, :]
# Out:
# 3
# תאריך                                                                                                                                                                                  תאריך
# תאריך ערך                                                                                                                                                                          תאריך ערך
# סוג תנועה                                                                                                                                                                          סוג תנועה
# זכות                                                                                                                                                                                    זכות
# חובה                                                                                                                                                                                    חובה
# יתרה בש"ח                                                                                                                                                                          יתרה בש"ח
# אסמכתא                                                                                                                                                                                אסמכתא
# AccountActivity (1).xls                                                                                                                                              AccountActivity (1).xls
# C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi\AccountActivity (1).xls    C:\Users\shai\Documents\personal\personal_proj...
# .xls                                                                                                                                                                                    .xls
# mizrachi_read_html_table_1                                                                                                                                        mizrachi_read_html_table_1
# Name: 3, dtype: object

# %%
df_pending.columns
# Out:
# Index(['תאריך', 'תאריך ערך', 'סוג תנועה', 'זכות', 'חובה', 'יתרה בש"ח',
#        'אסמכתא', 'AccountActivity (1).xls',
#        'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi\AccountActivity (1).xls',
#        '.xls', 'mizrachi_read_html_table_1'],
#       dtype='object', name=3)

# %%
df_pending
# Out:
# 3                                               תאריך  תאריך ערך  \
# 0                                        יתרה בחשבון:   29856.69
# 1                                        מסגרת אשראי:   20000.00
# 2                                      תנועות אחרונות        NaN
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
# 3                סוג תנועה            זכות      חובה  יתרה בש"ח    אסמכתא  \
# 0                 לתאריך -  05/03/26 23:15       NaN        NaN       NaN
# 1                      NaN             NaN       NaN        NaN       NaN
# 2                      NaN             NaN       NaN        NaN       NaN
# 3                סוג תנועה            זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)             NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)             NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)             NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)             NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)             NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)         3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)          112.00       NaN     338.93     13104
# 11              ריבית עו"ש           13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)         3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)         5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)             NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)             NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)             NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)         4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)             NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)          115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)         5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)         5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)             NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)        17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)        20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)             NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)             NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)             NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)             NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)          946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)             NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)             NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)             NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)          115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)          219.00       NaN   30216.69     63051
# 36                     NaN             NaN       NaN        NaN       NaN
# 37                     NaN             NaN       NaN        NaN       NaN
#
# 3   AccountActivity (1).xls  \
# 0   AccountActivity (1).xls
# 1   AccountActivity (1).xls
# 2   AccountActivity (1).xls
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
# 3  C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi\AccountActivity (1).xls  \
# 0   C:\Users\shai\Documents\personal\personal_proj...
# 1   C:\Users\shai\Documents\personal\personal_proj...
# 2   C:\Users\shai\Documents\personal\personal_proj...
# 3   C:\Users\shai\Documents\personal\personal_proj...
# 4   C:\Users\shai\Documents\personal\personal_proj...
# 5   C:\Users\shai\Documents\personal\personal_proj...
# 6   C:\Users\shai\Documents\personal\personal_proj...
# 7   C:\Users\shai\Documents\personal\personal_proj...
# 8   C:\Users\shai\Documents\personal\personal_proj...
# 9   C:\Users\shai\Documents\personal\personal_proj...
# 10  C:\Users\shai\Documents\personal\personal_proj...
# 11  C:\Users\shai\Documents\personal\personal_proj...
# 12  C:\Users\shai\Documents\personal\personal_proj...
# 13  C:\Users\shai\Documents\personal\personal_proj...
# 14  C:\Users\shai\Documents\personal\personal_proj...
# 15  C:\Users\shai\Documents\personal\personal_proj...
# 16  C:\Users\shai\Documents\personal\personal_proj...
# 17  C:\Users\shai\Documents\personal\personal_proj...
# 18  C:\Users\shai\Documents\personal\personal_proj...
# 19  C:\Users\shai\Documents\personal\personal_proj...
# 20  C:\Users\shai\Documents\personal\personal_proj...
# 21  C:\Users\shai\Documents\personal\personal_proj...
# 22  C:\Users\shai\Documents\personal\personal_proj...
# 23  C:\Users\shai\Documents\personal\personal_proj...
# 24  C:\Users\shai\Documents\personal\personal_proj...
# 25  C:\Users\shai\Documents\personal\personal_proj...
# 26  C:\Users\shai\Documents\personal\personal_proj...
# 27  C:\Users\shai\Documents\personal\personal_proj...
# 28  C:\Users\shai\Documents\personal\personal_proj...
# 29  C:\Users\shai\Documents\personal\personal_proj...
# 30  C:\Users\shai\Documents\personal\personal_proj...
# 31  C:\Users\shai\Documents\personal\personal_proj...
# 32  C:\Users\shai\Documents\personal\personal_proj...
# 33  C:\Users\shai\Documents\personal\personal_proj...
# 34  C:\Users\shai\Documents\personal\personal_proj...
# 35  C:\Users\shai\Documents\personal\personal_proj...
# 36  C:\Users\shai\Documents\personal\personal_proj...
# 37  C:\Users\shai\Documents\personal\personal_proj...
#
# 3   .xls  mizrachi_read_html_table_1
# 0   .xls  mizrachi_read_html_table_1
# 1   .xls  mizrachi_read_html_table_1
# 2   .xls  mizrachi_read_html_table_1
# 3   .xls  mizrachi_read_html_table_1
# 4   .xls  mizrachi_read_html_table_1
# 5   .xls  mizrachi_read_html_table_1
# 6   .xls  mizrachi_read_html_table_1
# 7   .xls  mizrachi_read_html_table_1
# 8   .xls  mizrachi_read_html_table_1
# 9   .xls  mizrachi_read_html_table_1
# 10  .xls  mizrachi_read_html_table_1
# 11  .xls  mizrachi_read_html_table_1
# 12  .xls  mizrachi_read_html_table_1
# 13  .xls  mizrachi_read_html_table_1
# 14  .xls  mizrachi_read_html_table_1
# 15  .xls  mizrachi_read_html_table_1
# 16  .xls  mizrachi_read_html_table_1
# 17  .xls  mizrachi_read_html_table_1
# 18  .xls  mizrachi_read_html_table_1
# 19  .xls  mizrachi_read_html_table_1
# 20  .xls  mizrachi_read_html_table_1
# 21  .xls  mizrachi_read_html_table_1
# 22  .xls  mizrachi_read_html_table_1
# 23  .xls  mizrachi_read_html_table_1
# 24  .xls  mizrachi_read_html_table_1
# 25  .xls  mizrachi_read_html_table_1
# 26  .xls  mizrachi_read_html_table_1
# 27  .xls  mizrachi_read_html_table_1
# 28  .xls  mizrachi_read_html_table_1
# 29  .xls  mizrachi_read_html_table_1
# 30  .xls  mizrachi_read_html_table_1
# 31  .xls  mizrachi_read_html_table_1
# 32  .xls  mizrachi_read_html_table_1
# 33  .xls  mizrachi_read_html_table_1
# 34  .xls  mizrachi_read_html_table_1
# 35  .xls  mizrachi_read_html_table_1
# 36  .xls  mizrachi_read_html_table_1
# 37  .xls  mizrachi_read_html_table_1

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Header row detection
# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)
df_pending.columns = df_pending.iloc[header_row_idx, :]
df_pending = df_pending.iloc[header_row_idx+1:]
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending
# Out:
# 3                                               תאריך תאריך ערך  \
# 4                                            10/12/25       NaN
# 5                                            10/12/25       NaN
# 6                                            10/12/25       NaN
# 7                                            11/12/25       NaN
# 8                                            15/12/25       NaN
# 9                                            16/12/25       NaN
# 10                                           21/12/25       NaN
# 11                                           01/01/26       NaN
# 12                                           04/01/26       NaN
# 13                                           04/01/26       NaN
# 14                                           11/01/26       NaN
# 15                                           11/01/26       NaN
# 16                                           11/01/26       NaN
# 17                                           11/01/26       NaN
# 18                                           12/01/26       NaN
# 19                                           15/01/26       NaN
# 20                                           20/01/26       NaN
# 21                                           01/02/26       NaN
# 22                                           04/02/26       NaN
# 23                                           06/02/26       NaN
# 24                                           08/02/26       NaN
# 25                                           10/02/26       NaN
# 26                                           10/02/26       NaN
# 27                                           10/02/26       NaN
# 28                                           10/02/26       NaN
# 29                                           10/02/26       NaN
# 30                                           13/02/26       NaN
# 31                                           13/02/26       NaN
# 32                                           15/02/26       NaN
# 33                                           15/02/26       NaN
# 34                                           20/02/26       NaN
# 35                                           25/02/26       NaN
# 36                                        תנועות היום       NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...       NaN
#
# 3                סוג תנועה      זכות      חובה יתרה בש"ח    אסמכתא  \
# 4      ביצוע הוראת קבע (י)       NaN    600.00   9451.53        29
# 5        הרשאה ישראכרט (י)       NaN   2874.04       NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)       NaN   1000.00   5577.49     57318
# 7         טן חברה לדלק (י)       NaN    481.84   5095.65     27839
# 8   הרשאה מקס איט פיננס(י)       NaN   7868.72  -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)   3000.00       NaN    226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)    112.00       NaN    338.93     13104
# 11              ריבית עו"ש     13.72       NaN    352.65  55555555
# 12  זיכוי - בנק הפועלים(י)   3200.00       NaN       NaN     99012
# 13  זיכוי - בנק הפועלים(י)   5000.00       NaN   8552.65     99012
# 14     ביצוע הוראת קבע (י)       NaN    600.00       NaN        29
# 15       הרשאה ישראכרט (י)       NaN   2504.63       NaN     20543
# 16        טן חברה לדלק (י)       NaN    476.61       NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)       NaN    800.00   4171.41     57318
# 18  זיכוי - בנק הפועלים(י)   4990.00       NaN   9161.41     99012
# 19  הרשאה מקס איט פיננס(י)       NaN   5875.55   3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)    115.00       NaN   3400.86     13104
# 21  זיכוי - בנק הפועלים(י)   5000.00       NaN   8400.86     99012
# 22  זיכוי - בנק הפועלים(י)   5000.00       NaN  13400.86     99012
# 23  הרשאה מקס איט פיננס(י)       NaN     62.78  13338.08     34685
# 24  זיכוי - בנק הפועלים(י)  17000.00       NaN  30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)  20315.00       NaN       NaN     63051
# 26     ביצוע הוראת קבע (י)       NaN    600.00       NaN        29
# 27       הרשאה ישראכרט (י)       NaN   3427.00       NaN     20543
# 28  הרשאה מקס איט פיננס(י)       NaN    500.00       NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)       NaN    800.00  45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)    946.00       NaN       NaN     63051
# 31      העברה באינטרנט (י)       NaN   2000.00  44272.08      6715
# 32  הרשאה מקס איט פיננס(י)       NaN  12989.39       NaN     34685
# 33      העברה באינטרנט (י)       NaN   1400.00  29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)    115.00       NaN  29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)    219.00       NaN  30216.69     63051
# 36                     NaN       NaN       NaN       NaN       NaN
# 37                     NaN       NaN       NaN       NaN       NaN
#
# 3   AccountActivity (1).xls  \
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
# 3  C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi\AccountActivity (1).xls  \
# 4   C:\Users\shai\Documents\personal\personal_proj...
# 5   C:\Users\shai\Documents\personal\personal_proj...
# 6   C:\Users\shai\Documents\personal\personal_proj...
# 7   C:\Users\shai\Documents\personal\personal_proj...
# 8   C:\Users\shai\Documents\personal\personal_proj...
# 9   C:\Users\shai\Documents\personal\personal_proj...
# 10  C:\Users\shai\Documents\personal\personal_proj...
# 11  C:\Users\shai\Documents\personal\personal_proj...
# 12  C:\Users\shai\Documents\personal\personal_proj...
# 13  C:\Users\shai\Documents\personal\personal_proj...
# 14  C:\Users\shai\Documents\personal\personal_proj...
# 15  C:\Users\shai\Documents\personal\personal_proj...
# 16  C:\Users\shai\Documents\personal\personal_proj...
# 17  C:\Users\shai\Documents\personal\personal_proj...
# 18  C:\Users\shai\Documents\personal\personal_proj...
# 19  C:\Users\shai\Documents\personal\personal_proj...
# 20  C:\Users\shai\Documents\personal\personal_proj...
# 21  C:\Users\shai\Documents\personal\personal_proj...
# 22  C:\Users\shai\Documents\personal\personal_proj...
# 23  C:\Users\shai\Documents\personal\personal_proj...
# 24  C:\Users\shai\Documents\personal\personal_proj...
# 25  C:\Users\shai\Documents\personal\personal_proj...
# 26  C:\Users\shai\Documents\personal\personal_proj...
# 27  C:\Users\shai\Documents\personal\personal_proj...
# 28  C:\Users\shai\Documents\personal\personal_proj...
# 29  C:\Users\shai\Documents\personal\personal_proj...
# 30  C:\Users\shai\Documents\personal\personal_proj...
# 31  C:\Users\shai\Documents\personal\personal_proj...
# 32  C:\Users\shai\Documents\personal\personal_proj...
# 33  C:\Users\shai\Documents\personal\personal_proj...
# 34  C:\Users\shai\Documents\personal\personal_proj...
# 35  C:\Users\shai\Documents\personal\personal_proj...
# 36  C:\Users\shai\Documents\personal\personal_proj...
# 37  C:\Users\shai\Documents\personal\personal_proj...
#
# 3   .xls  mizrachi_read_html_table_1
# 4   .xls  mizrachi_read_html_table_1
# 5   .xls  mizrachi_read_html_table_1
# 6   .xls  mizrachi_read_html_table_1
# 7   .xls  mizrachi_read_html_table_1
# 8   .xls  mizrachi_read_html_table_1
# 9   .xls  mizrachi_read_html_table_1
# 10  .xls  mizrachi_read_html_table_1
# 11  .xls  mizrachi_read_html_table_1
# 12  .xls  mizrachi_read_html_table_1
# 13  .xls  mizrachi_read_html_table_1
# 14  .xls  mizrachi_read_html_table_1
# 15  .xls  mizrachi_read_html_table_1
# 16  .xls  mizrachi_read_html_table_1
# 17  .xls  mizrachi_read_html_table_1
# 18  .xls  mizrachi_read_html_table_1
# 19  .xls  mizrachi_read_html_table_1
# 20  .xls  mizrachi_read_html_table_1
# 21  .xls  mizrachi_read_html_table_1
# 22  .xls  mizrachi_read_html_table_1
# 23  .xls  mizrachi_read_html_table_1
# 24  .xls  mizrachi_read_html_table_1
# 25  .xls  mizrachi_read_html_table_1
# 26  .xls  mizrachi_read_html_table_1
# 27  .xls  mizrachi_read_html_table_1
# 28  .xls  mizrachi_read_html_table_1
# 29  .xls  mizrachi_read_html_table_1
# 30  .xls  mizrachi_read_html_table_1
# 31  .xls  mizrachi_read_html_table_1
# 32  .xls  mizrachi_read_html_table_1
# 33  .xls  mizrachi_read_html_table_1
# 34  .xls  mizrachi_read_html_table_1
# 35  .xls  mizrachi_read_html_table_1
# 36  .xls  mizrachi_read_html_table_1
# 37  .xls  mizrachi_read_html_table_1

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
# Header row detection
# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)
df_pending.columns = df_pending.iloc[header_row_idx, :]

# %%
df_pending.iloc[header_row_idx:]
# Out:
# 3                                               תאריך  תאריך ערך  \
# 3                                               תאריך  תאריך ערך
# 4                                            10/12/25        NaN
# 5                                            10/12/25        NaN
# 6                                            10/12/25        NaN
# 7                                            11/12/25        NaN
# 8                                            15/12/25        NaN
# 9                                            16/12/25        NaN
# 10                                           21/12/25        NaN
# 11                                           01/01/26        NaN
# 12                                           04/01/26        NaN
# 13                                           04/01/26        NaN
# 14                                           11/01/26        NaN
# 15                                           11/01/26        NaN
# 16                                           11/01/26        NaN
# 17                                           11/01/26        NaN
# 18                                           12/01/26        NaN
# 19                                           15/01/26        NaN
# 20                                           20/01/26        NaN
# 21                                           01/02/26        NaN
# 22                                           04/02/26        NaN
# 23                                           06/02/26        NaN
# 24                                           08/02/26        NaN
# 25                                           10/02/26        NaN
# 26                                           10/02/26        NaN
# 27                                           10/02/26        NaN
# 28                                           10/02/26        NaN
# 29                                           10/02/26        NaN
# 30                                           13/02/26        NaN
# 31                                           13/02/26        NaN
# 32                                           15/02/26        NaN
# 33                                           15/02/26        NaN
# 34                                           20/02/26        NaN
# 35                                           25/02/26        NaN
# 36                                        תנועות היום        NaN
# 37  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...        NaN
#
# 3                סוג תנועה      זכות      חובה  יתרה בש"ח    אסמכתא  \
# 3                סוג תנועה      זכות      חובה  יתרה בש"ח    אסמכתא
# 4      ביצוע הוראת קבע (י)       NaN    600.00    9451.53        29
# 5        הרשאה ישראכרט (י)       NaN   2874.04        NaN     20543
# 6   מור גמל ופנסיה בע"מ(י)       NaN   1000.00    5577.49     57318
# 7         טן חברה לדלק (י)       NaN    481.84    5095.65     27839
# 8   הרשאה מקס איט פיננס(י)       NaN   7868.72   -2773.07     34685
# 9   זיכוי - בנק הפועלים(י)   3000.00       NaN     226.93     99012
# 10  ב. לאומי- קיצבת ילד(י)    112.00       NaN     338.93     13104
# 11              ריבית עו"ש     13.72       NaN     352.65  55555555
# 12  זיכוי - בנק הפועלים(י)   3200.00       NaN        NaN     99012
# 13  זיכוי - בנק הפועלים(י)   5000.00       NaN    8552.65     99012
# 14     ביצוע הוראת קבע (י)       NaN    600.00        NaN        29
# 15       הרשאה ישראכרט (י)       NaN   2504.63        NaN     20543
# 16        טן חברה לדלק (י)       NaN    476.61        NaN     27839
# 17  מור גמל ופנסיה בע"מ(י)       NaN    800.00    4171.41     57318
# 18  זיכוי - בנק הפועלים(י)   4990.00       NaN    9161.41     99012
# 19  הרשאה מקס איט פיננס(י)       NaN   5875.55    3285.86     34685
# 20  ב. לאומי- קיצבת ילד(י)    115.00       NaN    3400.86     13104
# 21  זיכוי - בנק הפועלים(י)   5000.00       NaN    8400.86     99012
# 22  זיכוי - בנק הפועלים(י)   5000.00       NaN   13400.86     99012
# 23  הרשאה מקס איט פיננס(י)       NaN     62.78   13338.08     34685
# 24  זיכוי - בנק הפועלים(י)  17000.00       NaN   30338.08     99012
# 25  ביטוח לאומי חד פעמי(י)  20315.00       NaN        NaN     63051
# 26     ביצוע הוראת קבע (י)       NaN    600.00        NaN        29
# 27       הרשאה ישראכרט (י)       NaN   3427.00        NaN     20543
# 28  הרשאה מקס איט פיננס(י)       NaN    500.00        NaN     34685
# 29  מור גמל ופנסיה בע"מ(י)       NaN    800.00   45326.08     57318
# 30  ביטוח לאומי חד פעמי(י)    946.00       NaN        NaN     63051
# 31      העברה באינטרנט (י)       NaN   2000.00   44272.08      6715
# 32  הרשאה מקס איט פיננס(י)       NaN  12989.39        NaN     34685
# 33      העברה באינטרנט (י)       NaN   1400.00   29882.69     25643
# 34  ב. לאומי- קיצבת ילד(י)    115.00       NaN   29997.69     13104
# 35  ביטוח לאומי חד פעמי(י)    219.00       NaN   30216.69     63051
# 36                     NaN       NaN       NaN        NaN       NaN
# 37                     NaN       NaN       NaN        NaN       NaN
#
# 3   AccountActivity (1).xls  \
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
# 34  AccountActivity (1).xls
# 35  AccountActivity (1).xls
# 36  AccountActivity (1).xls
# 37  AccountActivity (1).xls
#
# 3  C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi\AccountActivity (1).xls  \
# 3   C:\Users\shai\Documents\personal\personal_proj...
# 4   C:\Users\shai\Documents\personal\personal_proj...
# 5   C:\Users\shai\Documents\personal\personal_proj...
# 6   C:\Users\shai\Documents\personal\personal_proj...
# 7   C:\Users\shai\Documents\personal\personal_proj...
# 8   C:\Users\shai\Documents\personal\personal_proj...
# 9   C:\Users\shai\Documents\personal\personal_proj...
# 10  C:\Users\shai\Documents\personal\personal_proj...
# 11  C:\Users\shai\Documents\personal\personal_proj...
# 12  C:\Users\shai\Documents\personal\personal_proj...
# 13  C:\Users\shai\Documents\personal\personal_proj...
# 14  C:\Users\shai\Documents\personal\personal_proj...
# 15  C:\Users\shai\Documents\personal\personal_proj...
# 16  C:\Users\shai\Documents\personal\personal_proj...
# 17  C:\Users\shai\Documents\personal\personal_proj...
# 18  C:\Users\shai\Documents\personal\personal_proj...
# 19  C:\Users\shai\Documents\personal\personal_proj...
# 20  C:\Users\shai\Documents\personal\personal_proj...
# 21  C:\Users\shai\Documents\personal\personal_proj...
# 22  C:\Users\shai\Documents\personal\personal_proj...
# 23  C:\Users\shai\Documents\personal\personal_proj...
# 24  C:\Users\shai\Documents\personal\personal_proj...
# 25  C:\Users\shai\Documents\personal\personal_proj...
# 26  C:\Users\shai\Documents\personal\personal_proj...
# 27  C:\Users\shai\Documents\personal\personal_proj...
# 28  C:\Users\shai\Documents\personal\personal_proj...
# 29  C:\Users\shai\Documents\personal\personal_proj...
# 30  C:\Users\shai\Documents\personal\personal_proj...
# 31  C:\Users\shai\Documents\personal\personal_proj...
# 32  C:\Users\shai\Documents\personal\personal_proj...
# 33  C:\Users\shai\Documents\personal\personal_proj...
# 34  C:\Users\shai\Documents\personal\personal_proj...
# 35  C:\Users\shai\Documents\personal\personal_proj...
# 36  C:\Users\shai\Documents\personal\personal_proj...
# 37  C:\Users\shai\Documents\personal\personal_proj...
#
# 3   .xls  mizrachi_read_html_table_1
# 3   .xls  mizrachi_read_html_table_1
# 4   .xls  mizrachi_read_html_table_1
# 5   .xls  mizrachi_read_html_table_1
# 6   .xls  mizrachi_read_html_table_1
# 7   .xls  mizrachi_read_html_table_1
# 8   .xls  mizrachi_read_html_table_1
# 9   .xls  mizrachi_read_html_table_1
# 10  .xls  mizrachi_read_html_table_1
# 11  .xls  mizrachi_read_html_table_1
# 12  .xls  mizrachi_read_html_table_1
# 13  .xls  mizrachi_read_html_table_1
# 14  .xls  mizrachi_read_html_table_1
# 15  .xls  mizrachi_read_html_table_1
# 16  .xls  mizrachi_read_html_table_1
# 17  .xls  mizrachi_read_html_table_1
# 18  .xls  mizrachi_read_html_table_1
# 19  .xls  mizrachi_read_html_table_1
# 20  .xls  mizrachi_read_html_table_1
# 21  .xls  mizrachi_read_html_table_1
# 22  .xls  mizrachi_read_html_table_1
# 23  .xls  mizrachi_read_html_table_1
# 24  .xls  mizrachi_read_html_table_1
# 25  .xls  mizrachi_read_html_table_1
# 26  .xls  mizrachi_read_html_table_1
# 27  .xls  mizrachi_read_html_table_1
# 28  .xls  mizrachi_read_html_table_1
# 29  .xls  mizrachi_read_html_table_1
# 30  .xls  mizrachi_read_html_table_1
# 31  .xls  mizrachi_read_html_table_1
# 32  .xls  mizrachi_read_html_table_1
# 33  .xls  mizrachi_read_html_table_1
# 34  .xls  mizrachi_read_html_table_1
# 35  .xls  mizrachi_read_html_table_1
# 36  .xls  mizrachi_read_html_table_1
# 37  .xls  mizrachi_read_html_table_1

# %%
path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
dates_range = ("01/01/2026", "01/03/2026")

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
import pandas as pd


def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
    

    # Header row detection
    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_header_row_mizrachi_case(df_pending)
    df_pending = apply_detected_header(df_pending, header_row_idx)

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Header row detection
# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)
df_pending = apply_detected_header(df_pending, header_row_idx)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending
# Out:
#                                                 תאריך תאריך ערך  \
# 0                                            10/12/25       NaN
# 1                                            10/12/25       NaN
# 2                                            10/12/25       NaN
# 3                                            11/12/25       NaN
# 4                                            15/12/25       NaN
# 5                                            16/12/25       NaN
# 6                                            21/12/25       NaN
# 7                                            01/01/26       NaN
# 8                                            04/01/26       NaN
# 9                                            04/01/26       NaN
# 10                                           11/01/26       NaN
# 11                                           11/01/26       NaN
# 12                                           11/01/26       NaN
# 13                                           11/01/26       NaN
# 14                                           12/01/26       NaN
# 15                                           15/01/26       NaN
# 16                                           20/01/26       NaN
# 17                                           01/02/26       NaN
# 18                                           04/02/26       NaN
# 19                                           06/02/26       NaN
# 20                                           08/02/26       NaN
# 21                                           10/02/26       NaN
# 22                                           10/02/26       NaN
# 23                                           10/02/26       NaN
# 24                                           10/02/26       NaN
# 25                                           10/02/26       NaN
# 26                                           13/02/26       NaN
# 27                                           13/02/26       NaN
# 28                                           15/02/26       NaN
# 29                                           15/02/26       NaN
# 30                                           20/02/26       NaN
# 31                                           25/02/26       NaN
# 32                                        תנועות היום       NaN
# 33  תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...       NaN
#
#                  סוג תנועה      זכות      חובה יתרה בש"ח    אסמכתא  \
# 0      ביצוע הוראת קבע (י)       NaN    600.00   9451.53        29
# 1        הרשאה ישראכרט (י)       NaN   2874.04       NaN     20543
# 2   מור גמל ופנסיה בע"מ(י)       NaN   1000.00   5577.49     57318
# 3         טן חברה לדלק (י)       NaN    481.84   5095.65     27839
# 4   הרשאה מקס איט פיננס(י)       NaN   7868.72  -2773.07     34685
# 5   זיכוי - בנק הפועלים(י)   3000.00       NaN    226.93     99012
# 6   ב. לאומי- קיצבת ילד(י)    112.00       NaN    338.93     13104
# 7               ריבית עו"ש     13.72       NaN    352.65  55555555
# 8   זיכוי - בנק הפועלים(י)   3200.00       NaN       NaN     99012
# 9   זיכוי - בנק הפועלים(י)   5000.00       NaN   8552.65     99012
# 10     ביצוע הוראת קבע (י)       NaN    600.00       NaN        29
# 11       הרשאה ישראכרט (י)       NaN   2504.63       NaN     20543
# 12        טן חברה לדלק (י)       NaN    476.61       NaN     27839
# 13  מור גמל ופנסיה בע"מ(י)       NaN    800.00   4171.41     57318
# 14  זיכוי - בנק הפועלים(י)   4990.00       NaN   9161.41     99012
# 15  הרשאה מקס איט פיננס(י)       NaN   5875.55   3285.86     34685
# 16  ב. לאומי- קיצבת ילד(י)    115.00       NaN   3400.86     13104
# 17  זיכוי - בנק הפועלים(י)   5000.00       NaN   8400.86     99012
# 18  זיכוי - בנק הפועלים(י)   5000.00       NaN  13400.86     99012
# 19  הרשאה מקס איט פיננס(י)       NaN     62.78  13338.08     34685
# 20  זיכוי - בנק הפועלים(י)  17000.00       NaN  30338.08     99012
# 21  ביטוח לאומי חד פעמי(י)  20315.00       NaN       NaN     63051
# 22     ביצוע הוראת קבע (י)       NaN    600.00       NaN        29
# 23       הרשאה ישראכרט (י)       NaN   3427.00       NaN     20543
# 24  הרשאה מקס איט פיננס(י)       NaN    500.00       NaN     34685
# 25  מור גמל ופנסיה בע"מ(י)       NaN    800.00  45326.08     57318
# 26  ביטוח לאומי חד פעמי(י)    946.00       NaN       NaN     63051
# 27      העברה באינטרנט (י)       NaN   2000.00  44272.08      6715
# 28  הרשאה מקס איט פיננס(י)       NaN  12989.39       NaN     34685
# 29      העברה באינטרנט (י)       NaN   1400.00  29882.69     25643
# 30  ב. לאומי- קיצבת ילד(י)    115.00       NaN  29997.69     13104
# 31  ביטוח לאומי חד פעמי(י)    219.00       NaN  30216.69     63051
# 32                     NaN       NaN       NaN       NaN       NaN
# 33                     NaN       NaN       NaN       NaN       NaN
#
#     AccountActivity (1).xls  \
# 0   AccountActivity (1).xls
# 1   AccountActivity (1).xls
# 2   AccountActivity (1).xls
# 3   AccountActivity (1).xls
# 4   AccountActivity (1).xls
# 5   AccountActivity (1).xls
# 6   AccountActivity (1).xls
# 7   AccountActivity (1).xls
# 8   AccountActivity (1).xls
# 9   AccountActivity (1).xls
# 10  AccountActivity (1).xls
# 11  AccountActivity (1).xls
# 12  AccountActivity (1).xls
# 13  AccountActivity (1).xls
# 14  AccountActivity (1).xls
# 15  AccountActivity (1).xls
# 16  AccountActivity (1).xls
# 17  AccountActivity (1).xls
# 18  AccountActivity (1).xls
# 19  AccountActivity (1).xls
# 20  AccountActivity (1).xls
# 21  AccountActivity (1).xls
# 22  AccountActivity (1).xls
# 23  AccountActivity (1).xls
# 24  AccountActivity (1).xls
# 25  AccountActivity (1).xls
# 26  AccountActivity (1).xls
# 27  AccountActivity (1).xls
# 28  AccountActivity (1).xls
# 29  AccountActivity (1).xls
# 30  AccountActivity (1).xls
# 31  AccountActivity (1).xls
# 32  AccountActivity (1).xls
# 33  AccountActivity (1).xls
#
#    C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi\AccountActivity (1).xls  \
# 0   C:\Users\shai\Documents\personal\personal_proj...
# 1   C:\Users\shai\Documents\personal\personal_proj...
# 2   C:\Users\shai\Documents\personal\personal_proj...
# 3   C:\Users\shai\Documents\personal\personal_proj...
# 4   C:\Users\shai\Documents\personal\personal_proj...
# 5   C:\Users\shai\Documents\personal\personal_proj...
# 6   C:\Users\shai\Documents\personal\personal_proj...
# 7   C:\Users\shai\Documents\personal\personal_proj...
# 8   C:\Users\shai\Documents\personal\personal_proj...
# 9   C:\Users\shai\Documents\personal\personal_proj...
# 10  C:\Users\shai\Documents\personal\personal_proj...
# 11  C:\Users\shai\Documents\personal\personal_proj...
# 12  C:\Users\shai\Documents\personal\personal_proj...
# 13  C:\Users\shai\Documents\personal\personal_proj...
# 14  C:\Users\shai\Documents\personal\personal_proj...
# 15  C:\Users\shai\Documents\personal\personal_proj...
# 16  C:\Users\shai\Documents\personal\personal_proj...
# 17  C:\Users\shai\Documents\personal\personal_proj...
# 18  C:\Users\shai\Documents\personal\personal_proj...
# 19  C:\Users\shai\Documents\personal\personal_proj...
# 20  C:\Users\shai\Documents\personal\personal_proj...
# 21  C:\Users\shai\Documents\personal\personal_proj...
# 22  C:\Users\shai\Documents\personal\personal_proj...
# 23  C:\Users\shai\Documents\personal\personal_proj...
# 24  C:\Users\shai\Documents\personal\personal_proj...
# 25  C:\Users\shai\Documents\personal\personal_proj...
# 26  C:\Users\shai\Documents\personal\personal_proj...
# 27  C:\Users\shai\Documents\personal\personal_proj...
# 28  C:\Users\shai\Documents\personal\personal_proj...
# 29  C:\Users\shai\Documents\personal\personal_proj...
# 30  C:\Users\shai\Documents\personal\personal_proj...
# 31  C:\Users\shai\Documents\personal\personal_proj...
# 32  C:\Users\shai\Documents\personal\personal_proj...
# 33  C:\Users\shai\Documents\personal\personal_proj...
#
#     .xls  mizrachi_read_html_table_1
# 0   .xls  mizrachi_read_html_table_1
# 1   .xls  mizrachi_read_html_table_1
# 2   .xls  mizrachi_read_html_table_1
# 3   .xls  mizrachi_read_html_table_1
# 4   .xls  mizrachi_read_html_table_1
# 5   .xls  mizrachi_read_html_table_1
# 6   .xls  mizrachi_read_html_table_1
# 7   .xls  mizrachi_read_html_table_1
# 8   .xls  mizrachi_read_html_table_1
# 9   .xls  mizrachi_read_html_table_1
# 10  .xls  mizrachi_read_html_table_1
# 11  .xls  mizrachi_read_html_table_1
# 12  .xls  mizrachi_read_html_table_1
# 13  .xls  mizrachi_read_html_table_1
# 14  .xls  mizrachi_read_html_table_1
# 15  .xls  mizrachi_read_html_table_1
# 16  .xls  mizrachi_read_html_table_1
# 17  .xls  mizrachi_read_html_table_1
# 18  .xls  mizrachi_read_html_table_1
# 19  .xls  mizrachi_read_html_table_1
# 20  .xls  mizrachi_read_html_table_1
# 21  .xls  mizrachi_read_html_table_1
# 22  .xls  mizrachi_read_html_table_1
# 23  .xls  mizrachi_read_html_table_1
# 24  .xls  mizrachi_read_html_table_1
# 25  .xls  mizrachi_read_html_table_1
# 26  .xls  mizrachi_read_html_table_1
# 27  .xls  mizrachi_read_html_table_1
# 28  .xls  mizrachi_read_html_table_1
# 29  .xls  mizrachi_read_html_table_1
# 30  .xls  mizrachi_read_html_table_1
# 31  .xls  mizrachi_read_html_table_1
# 32  .xls  mizrachi_read_html_table_1
# 33  .xls  mizrachi_read_html_table_1

# %%
GLOBAL_TRNASLATION_MAP = {
    'תאריך': 'Date',
    'סוג תנועה': 'Payee',
    'זכות': 'Inflow',
    'חובה': 'Outflow'
}

# %%
DATE_FORMAT = '%d/%m/%Y'

# %%
pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)

# %%
pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "10/12/25" doesn't match format "%d/%m/%Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
1+1
# Out:
# 2

# %%
pd
# Out:
# <module 'pandas' from 'c:\\Users\\shai\\miniconda3\\envs\\venv_nadlan_311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
pd.to_datetime(
    df_pending["Date"].astype(str).str.strip(),
    format=DATE_FORMAT,
    errors="coerce",
)
# Out:
# 0    NaT
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 8    NaT
# 9    NaT
# 10   NaT
# 11   NaT
# 12   NaT
# 13   NaT
# 14   NaT
# 15   NaT
# 16   NaT
# 17   NaT
# 18   NaT
# 19   NaT
# 20   NaT
# 21   NaT
# 22   NaT
# 23   NaT
# 24   NaT
# 25   NaT
# 26   NaT
# 27   NaT
# 28   NaT
# 29   NaT
# 30   NaT
# 31   NaT
# 32   NaT
# 33   NaT
# Name: Date, dtype: datetime64[ns]

# %%
pd.to_datetime(df_pending["Date"].astype(str).str.strip(), format="%d/%m/%y", errors="coerce")
# Out:
# 0    2025-12-10
# 1    2025-12-10
# 2    2025-12-10
# 3    2025-12-11
# 4    2025-12-15
# 5    2025-12-16
# 6    2025-12-21
# 7    2026-01-01
# 8    2026-01-04
# 9    2026-01-04
# 10   2026-01-11
# 11   2026-01-11
# 12   2026-01-11
# 13   2026-01-11
# 14   2026-01-12
# 15   2026-01-15
# 16   2026-01-20
# 17   2026-02-01
# 18   2026-02-04
# 19   2026-02-06
# 20   2026-02-08
# 21   2026-02-10
# 22   2026-02-10
# 23   2026-02-10
# 24   2026-02-10
# 25   2026-02-10
# 26   2026-02-13
# 27   2026-02-13
# 28   2026-02-15
# 29   2026-02-15
# 30   2026-02-20
# 31   2026-02-25
# 32          NaT
# 33          NaT
# Name: Date, dtype: datetime64[ns]

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
import pandas as pd

GLOBAL_TRNASLATION_MAP = {
    'תאריך': 'Date',
    'סוג תנועה': 'Payee',
    'זכות': 'Inflow',
    'חובה': 'Outflow'
}

DATE_FORMAT = '%d/%m/%Y'

def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


def parse_mizrachi_dates(raw_date_col: pd.Series, date_format: str = '%d/%m/%Y') -> pd.Series:
    # Clean raw values
    s = raw_date_col.astype(str).str.strip()
    s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})
    # First pass: dd/mm/yy
    parsed = pd.to_datetime(s, format=date_format, errors="coerce")
    # Second pass (only failed rows): dd/mm/yyyy
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_format,
        errors="coerce",
    )
    return parsed


def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
    

    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_header_row_mizrachi_case(df_pending)

    df_pending = apply_detected_header(df_pending, header_row_idx)

    # find last footer of dataframe  using date column (non date values) or     
    # dataframe has been aligned to the header row

    # translating columns names using global mapping (for this project)
    df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)
    
    # Align dates to dd/mm/YYYY format + drop rows with invalid dates
    df_pending['Date'] = pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
    parsed_dates = parse_mizrachi_dates(df_pending['Date'], DATE_FORMAT)



    #  
# STEP: parse date
# STEP: split inflow/outflow
# TODO: handle installment rows


if __name__ == "__main__":
    path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
    dates_range = ("01/01/2026", "01/03/2026")
    main(path_to_folder=path_to_folder, dates_range=dates_range)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 130
#     128 path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
#     129 dates_range = ("01/01/2026", "01/03/2026")
# --> 130 main(path_to_folder=path_to_folder, dates_range=dates_range)
#
# Cell In[90], line 116, in main(path_to_folder, dates_range)
#     113 df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)
#     115 # Align dates to dd/mm/YYYY format + drop rows with invalid dates
# --> 116 df_pending['Date'] = pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
#     117 parsed_dates = parse_mizrachi_dates(df_pending['Date'], DATE_FORMAT)
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "10/12/25" doesn't match format "%d/%m/%Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
dates_range = ("01/01/2026", "01/03/2026")

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)

df_pending = apply_detected_header(df_pending, header_row_idx)

# find last footer of dataframe  using date column (non date values) or     
# dataframe has been aligned to the header row

# translating columns names using global mapping (for this project)
df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)

# Align dates to dd/mm/YYYY format + drop rows with invalid dates
df_pending['Date'] = pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
parsed_dates = parse_mizrachi_dates(df_pending['Date'], DATE_FORMAT)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 25
#      22 df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)
#      24 # Align dates to dd/mm/YYYY format + drop rows with invalid dates
# ---> 25 df_pending['Date'] = pd.to_datetime(df_pending['Date'], format=DATE_FORMAT).dt.strftime(DATE_FORMAT)
#      26 parsed_dates = parse_mizrachi_dates(df_pending['Date'], DATE_FORMAT)
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\shai\miniconda3\envs\venv_nadlan_311\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "10/12/25" doesn't match format "%d/%m/%Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
parsed_dates = parse_mizrachi_dates(df_pending['Date'], DATE_FORMAT)

# %%
parsed_dates
# Out:
# 0    NaT
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 8    NaT
# 9    NaT
# 10   NaT
# 11   NaT
# 12   NaT
# 13   NaT
# 14   NaT
# 15   NaT
# 16   NaT
# 17   NaT
# 18   NaT
# 19   NaT
# 20   NaT
# 21   NaT
# 22   NaT
# 23   NaT
# 24   NaT
# 25   NaT
# 26   NaT
# 27   NaT
# 28   NaT
# 29   NaT
# 30   NaT
# 31   NaT
# 32   NaT
# 33   NaT
# Name: Date, dtype: datetime64[ns]

# %%
|
# Out:
#   Cell In[95], line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
import pandas as pd

GLOBAL_TRNASLATION_MAP = {
    'תאריך': 'Date',
    'סוג תנועה': 'Payee',
    'זכות': 'Inflow',
    'חובה': 'Outflow'
}

DATE_FORMAT = '%d/%m/%Y'
MIZRACHI_DATE_FORMAT = '%d/%m/%y'

def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


def parse_mizrachi_dates(raw_date_col: pd.Series, date_format: str = '%d/%m/%Y') -> pd.Series:
    # Clean raw values
    s = raw_date_col.astype(str).str.strip()
    s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})
    # First pass: dd/mm/yy
    parsed = pd.to_datetime(s, format=date_format, errors="coerce")
    # Second pass (only failed rows): dd/mm/yyyy
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_format,
        errors="coerce",
    )
    return parsed


def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
    

    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_header_row_mizrachi_case(df_pending)

    df_pending = apply_detected_header(df_pending, header_row_idx)

    # find last footer of dataframe  using date column (non date values) or     
    # dataframe has been aligned to the header row

    # translating columns names using global mapping (for this project)
    df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)
    
    # Align dates to dd/mm/YYYY format + drop rows with invalid dates
    parsed_dates = parse_mizrachi_dates(df_pending['Date'], MIZRACHI_DATE_FORMAT)



    #  
# STEP: parse date
# STEP: split inflow/outflow
# TODO: handle installment rows


if __name__ == "__main__":
    path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
    dates_range = ("01/01/2026", "01/03/2026")
    main(path_to_folder=path_to_folder, dates_range=dates_range)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
parsed_dates
# Out:
# 0    NaT
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 8    NaT
# 9    NaT
# 10   NaT
# 11   NaT
# 12   NaT
# 13   NaT
# 14   NaT
# 15   NaT
# 16   NaT
# 17   NaT
# 18   NaT
# 19   NaT
# 20   NaT
# 21   NaT
# 22   NaT
# 23   NaT
# 24   NaT
# 25   NaT
# 26   NaT
# 27   NaT
# 28   NaT
# 29   NaT
# 30   NaT
# 31   NaT
# 32   NaT
# 33   NaT
# Name: Date, dtype: datetime64[ns]

# %%
s =df_pending["Date"].astype(str).str.strip()

# %%
s
# Out:
# 0                                              10/12/25
# 1                                              10/12/25
# 2                                              10/12/25
# 3                                              11/12/25
# 4                                              15/12/25
# 5                                              16/12/25
# 6                                              21/12/25
# 7                                              01/01/26
# 8                                              04/01/26
# 9                                              04/01/26
# 10                                             11/01/26
# 11                                             11/01/26
# 12                                             11/01/26
# 13                                             11/01/26
# 14                                             12/01/26
# 15                                             15/01/26
# 16                                             20/01/26
# 17                                             01/02/26
# 18                                             04/02/26
# 19                                             06/02/26
# 20                                             08/02/26
# 21                                             10/02/26
# 22                                             10/02/26
# 23                                             10/02/26
# 24                                             10/02/26
# 25                                             10/02/26
# 26                                             13/02/26
# 27                                             13/02/26
# 28                                             15/02/26
# 29                                             15/02/26
# 30                                             20/02/26
# 31                                             25/02/26
# 32                                          תנועות היום
# 33    תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...
# Name: Date, dtype: object

# %%
s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})

# %%
s
# Out:
# 0                                              10/12/25
# 1                                              10/12/25
# 2                                              10/12/25
# 3                                              11/12/25
# 4                                              15/12/25
# 5                                              16/12/25
# 6                                              21/12/25
# 7                                              01/01/26
# 8                                              04/01/26
# 9                                              04/01/26
# 10                                             11/01/26
# 11                                             11/01/26
# 12                                             11/01/26
# 13                                             11/01/26
# 14                                             12/01/26
# 15                                             15/01/26
# 16                                             20/01/26
# 17                                             01/02/26
# 18                                             04/02/26
# 19                                             06/02/26
# 20                                             08/02/26
# 21                                             10/02/26
# 22                                             10/02/26
# 23                                             10/02/26
# 24                                             10/02/26
# 25                                             10/02/26
# 26                                             13/02/26
# 27                                             13/02/26
# 28                                             15/02/26
# 29                                             15/02/26
# 30                                             20/02/26
# 31                                             25/02/26
# 32                                          תנועות היום
# 33    תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...
# Name: Date, dtype: object

# %%
pd.to_datetime(s, format=date_format, errors="coerce")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 pd.to_datetime(s, format=date_format, errors="coerce")
#
# NameError: name 'date_format' is not defined

# %%
MIZRACHI_DATE_FORMAT = '%d/%m/%y'

# %%
pd.to_datetime(s, format=MIZRACHI_DATE_FORMAT, errors="coerce")
# Out:
# 0    2025-12-10
# 1    2025-12-10
# 2    2025-12-10
# 3    2025-12-11
# 4    2025-12-15
# 5    2025-12-16
# 6    2025-12-21
# 7    2026-01-01
# 8    2026-01-04
# 9    2026-01-04
# 10   2026-01-11
# 11   2026-01-11
# 12   2026-01-11
# 13   2026-01-11
# 14   2026-01-12
# 15   2026-01-15
# 16   2026-01-20
# 17   2026-02-01
# 18   2026-02-04
# 19   2026-02-06
# 20   2026-02-08
# 21   2026-02-10
# 22   2026-02-10
# 23   2026-02-10
# 24   2026-02-10
# 25   2026-02-10
# 26   2026-02-13
# 27   2026-02-13
# 28   2026-02-15
# 29   2026-02-15
# 30   2026-02-20
# 31   2026-02-25
# 32          NaT
# 33          NaT
# Name: Date, dtype: datetime64[ns]

# %%
parsed = pd.to_datetime(s, format=MIZRACHI_DATE_FORMAT, errors="coerce")

# %%
parsed
# Out:
# 0    2025-12-10
# 1    2025-12-10
# 2    2025-12-10
# 3    2025-12-11
# 4    2025-12-15
# 5    2025-12-16
# 6    2025-12-21
# 7    2026-01-01
# 8    2026-01-04
# 9    2026-01-04
# 10   2026-01-11
# 11   2026-01-11
# 12   2026-01-11
# 13   2026-01-11
# 14   2026-01-12
# 15   2026-01-15
# 16   2026-01-20
# 17   2026-02-01
# 18   2026-02-04
# 19   2026-02-06
# 20   2026-02-08
# 21   2026-02-10
# 22   2026-02-10
# 23   2026-02-10
# 24   2026-02-10
# 25   2026-02-10
# 26   2026-02-13
# 27   2026-02-13
# 28   2026-02-15
# 29   2026-02-15
# 30   2026-02-20
# 31   2026-02-25
# 32          NaT
# 33          NaT
# Name: Date, dtype: datetime64[ns]

# %%
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_format,
        errors="coerce",
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 4
#       1 missing = parsed.isna()
#       2 parsed.loc[missing] = pd.to_datetime(
#       3     s.loc[missing],
# ----> 4     format=date_format,
#       5     errors="coerce",
#       6 )
#
# NameError: name 'date_format' is not defined

# %%
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=MIZRACHI_DATE_FORMAT,
        errors="coerce",
    )

# %%
parsed
# Out:
# 0    2025-12-10
# 1    2025-12-10
# 2    2025-12-10
# 3    2025-12-11
# 4    2025-12-15
# 5    2025-12-16
# 6    2025-12-21
# 7    2026-01-01
# 8    2026-01-04
# 9    2026-01-04
# 10   2026-01-11
# 11   2026-01-11
# 12   2026-01-11
# 13   2026-01-11
# 14   2026-01-12
# 15   2026-01-15
# 16   2026-01-20
# 17   2026-02-01
# 18   2026-02-04
# 19   2026-02-06
# 20   2026-02-08
# 21   2026-02-10
# 22   2026-02-10
# 23   2026-02-10
# 24   2026-02-10
# 25   2026-02-10
# 26   2026-02-13
# 27   2026-02-13
# 28   2026-02-15
# 29   2026-02-15
# 30   2026-02-20
# 31   2026-02-25
# 32          NaT
# 33          NaT
# Name: Date, dtype: datetime64[ns]

# %%
s.loc[missing]
# Out:
# 32                                          תנועות היום
# 33    תנועות היום הן תנועות בחשבון שבוצעו ביום העסקי...
# Name: Date, dtype: object

# %% [markdown]
# Restarted venv_nadlan_311 (Python 3.11.13)

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
import pandas as pd

GLOBAL_TRNASLATION_MAP = {
    'תאריך': 'Date',
    'סוג תנועה': 'Payee',
    'זכות': 'Inflow',
    'חובה': 'Outflow'
}

DATE_FORMAT = '%d/%m/%Y'
MIZRACHI_DATE_FORMAT = '%d/%m/%y'

def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


def parse_mizrachi_dates(raw_date_col: pd.Series, date_format: str = '%d/%m/%Y') -> pd.Series:
    # Clean raw values
    s = raw_date_col.astype(str).str.strip()
    s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})
    # First pass: dd/mm/yy
    parsed = pd.to_datetime(s, format=date_format, errors="coerce")
    # Second pass (only failed rows): dd/mm/yyyy
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_format,
        errors="coerce",
    )
    return parsed


def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
    

    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_header_row_mizrachi_case(df_pending)

    df_pending = apply_detected_header(df_pending, header_row_idx)

    # find last footer of dataframe  using date column (non date values) or     
    # dataframe has been aligned to the header row

    # translating columns names using global mapping (for this project)
    df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)
    
    # Align dates to dd/mm/YYYY format + drop rows with invalid dates
    parsed_dates = parse_mizrachi_dates(df_pending['Date'], date_format=MIZRACHI_DATE_FORMAT)



    #  
# STEP: parse date
# STEP: split inflow/outflow
# TODO: handle installment rows


if __name__ == "__main__":
    path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
    dates_range = ("01/01/2026", "01/03/2026")
    main(path_to_folder=path_to_folder, dates_range=dates_range)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)

df_pending = apply_detected_header(df_pending, header_row_idx)

# find last footer of dataframe  using date column (non date values) or     
# dataframe has been aligned to the header row

# translating columns names using global mapping (for this project)
df_pending.columns = df_pending.columns.map(GLOBAL_TRNASLATION_MAP)

# Align dates to dd/mm/YYYY format + drop rows with invalid dates
parsed_dates = parse_mizrachi_dates(df_pending['Date'], date_format=MIZRACHI_DATE_FORMAT)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
parsed_dates
# Out:
# 0    2025-12-10
# 1    2025-12-10
# 2    2025-12-10
# 3    2025-12-11
# 4    2025-12-15
# 5    2025-12-16
# 6    2025-12-21
# 7    2026-01-01
# 8    2026-01-04
# 9    2026-01-04
# 10   2026-01-11
# 11   2026-01-11
# 12   2026-01-11
# 13   2026-01-11
# 14   2026-01-12
# 15   2026-01-15
# 16   2026-01-20
# 17   2026-02-01
# 18   2026-02-04
# 19   2026-02-06
# 20   2026-02-08
# 21   2026-02-10
# 22   2026-02-10
# 23   2026-02-10
# 24   2026-02-10
# 25   2026-02-10
# 26   2026-02-13
# 27   2026-02-13
# 28   2026-02-15
# 29   2026-02-15
# 30   2026-02-20
# 31   2026-02-25
# 32          NaT
# 33          NaT
# Name: Date, dtype: datetime64[ns]

# %%
valid_mask = parsed_dates.notna()
df_pending = df_pending.loc[valid_mask].copy()

# %%
valid_mask
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32    False
# 33    False
# Name: Date, dtype: bool

# %%
df_pending
# Out:
#         Date  NaN                   Payee    Inflow   Outflow       NaN  \
# 0   10/12/25  NaN     ביצוע הוראת קבע (י)       NaN    600.00   9451.53
# 1   10/12/25  NaN       הרשאה ישראכרט (י)       NaN   2874.04       NaN
# 2   10/12/25  NaN  מור גמל ופנסיה בע"מ(י)       NaN   1000.00   5577.49
# 3   11/12/25  NaN        טן חברה לדלק (י)       NaN    481.84   5095.65
# 4   15/12/25  NaN  הרשאה מקס איט פיננס(י)       NaN   7868.72  -2773.07
# 5   16/12/25  NaN  זיכוי - בנק הפועלים(י)   3000.00       NaN    226.93
# 6   21/12/25  NaN  ב. לאומי- קיצבת ילד(י)    112.00       NaN    338.93
# 7   01/01/26  NaN              ריבית עו"ש     13.72       NaN    352.65
# 8   04/01/26  NaN  זיכוי - בנק הפועלים(י)   3200.00       NaN       NaN
# 9   04/01/26  NaN  זיכוי - בנק הפועלים(י)   5000.00       NaN   8552.65
# 10  11/01/26  NaN     ביצוע הוראת קבע (י)       NaN    600.00       NaN
# 11  11/01/26  NaN       הרשאה ישראכרט (י)       NaN   2504.63       NaN
# 12  11/01/26  NaN        טן חברה לדלק (י)       NaN    476.61       NaN
# 13  11/01/26  NaN  מור גמל ופנסיה בע"מ(י)       NaN    800.00   4171.41
# 14  12/01/26  NaN  זיכוי - בנק הפועלים(י)   4990.00       NaN   9161.41
# 15  15/01/26  NaN  הרשאה מקס איט פיננס(י)       NaN   5875.55   3285.86
# 16  20/01/26  NaN  ב. לאומי- קיצבת ילד(י)    115.00       NaN   3400.86
# 17  01/02/26  NaN  זיכוי - בנק הפועלים(י)   5000.00       NaN   8400.86
# 18  04/02/26  NaN  זיכוי - בנק הפועלים(י)   5000.00       NaN  13400.86
# 19  06/02/26  NaN  הרשאה מקס איט פיננס(י)       NaN     62.78  13338.08
# 20  08/02/26  NaN  זיכוי - בנק הפועלים(י)  17000.00       NaN  30338.08
# 21  10/02/26  NaN  ביטוח לאומי חד פעמי(י)  20315.00       NaN       NaN
# 22  10/02/26  NaN     ביצוע הוראת קבע (י)       NaN    600.00       NaN
# 23  10/02/26  NaN       הרשאה ישראכרט (י)       NaN   3427.00       NaN
# 24  10/02/26  NaN  הרשאה מקס איט פיננס(י)       NaN    500.00       NaN
# 25  10/02/26  NaN  מור גמל ופנסיה בע"מ(י)       NaN    800.00  45326.08
# 26  13/02/26  NaN  ביטוח לאומי חד פעמי(י)    946.00       NaN       NaN
# 27  13/02/26  NaN      העברה באינטרנט (י)       NaN   2000.00  44272.08
# 28  15/02/26  NaN  הרשאה מקס איט פיננס(י)       NaN  12989.39       NaN
# 29  15/02/26  NaN      העברה באינטרנט (י)       NaN   1400.00  29882.69
# 30  20/02/26  NaN  ב. לאומי- קיצבת ילד(י)    115.00       NaN  29997.69
# 31  25/02/26  NaN  ביטוח לאומי חד פעמי(י)    219.00       NaN  30216.69
#
#          NaN                      NaN  \
# 0         29  AccountActivity (1).xls
# 1      20543  AccountActivity (1).xls
# 2      57318  AccountActivity (1).xls
# 3      27839  AccountActivity (1).xls
# 4      34685  AccountActivity (1).xls
# 5      99012  AccountActivity (1).xls
# 6      13104  AccountActivity (1).xls
# 7   55555555  AccountActivity (1).xls
# 8      99012  AccountActivity (1).xls
# 9      99012  AccountActivity (1).xls
# 10        29  AccountActivity (1).xls
# 11     20543  AccountActivity (1).xls
# 12     27839  AccountActivity (1).xls
# 13     57318  AccountActivity (1).xls
# 14     99012  AccountActivity (1).xls
# 15     34685  AccountActivity (1).xls
# 16     13104  AccountActivity (1).xls
# 17     99012  AccountActivity (1).xls
# 18     99012  AccountActivity (1).xls
# 19     34685  AccountActivity (1).xls
# 20     99012  AccountActivity (1).xls
# 21     63051  AccountActivity (1).xls
# 22        29  AccountActivity (1).xls
# 23     20543  AccountActivity (1).xls
# 24     34685  AccountActivity (1).xls
# 25     57318  AccountActivity (1).xls
# 26     63051  AccountActivity (1).xls
# 27      6715  AccountActivity (1).xls
# 28     34685  AccountActivity (1).xls
# 29     25643  AccountActivity (1).xls
# 30     13104  AccountActivity (1).xls
# 31     63051  AccountActivity (1).xls
#
#                                                   NaN   NaN  \
# 0   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 1   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 2   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 3   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...  .xls
#
#                            NaN
# 0   mizrachi_read_html_table_1
# 1   mizrachi_read_html_table_1
# 2   mizrachi_read_html_table_1
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1

# %%
parsed_dates.loc[valid_mask].dt.strftime(DATE_FORMAT)
# Out:
# 0     10/12/2025
# 1     10/12/2025
# 2     10/12/2025
# 3     11/12/2025
# 4     15/12/2025
# 5     16/12/2025
# 6     21/12/2025
# 7     01/01/2026
# 8     04/01/2026
# 9     04/01/2026
# 10    11/01/2026
# 11    11/01/2026
# 12    11/01/2026
# 13    11/01/2026
# 14    12/01/2026
# 15    15/01/2026
# 16    20/01/2026
# 17    01/02/2026
# 18    04/02/2026
# 19    06/02/2026
# 20    08/02/2026
# 21    10/02/2026
# 22    10/02/2026
# 23    10/02/2026
# 24    10/02/2026
# 25    10/02/2026
# 26    13/02/2026
# 27    13/02/2026
# 28    15/02/2026
# 29    15/02/2026
# 30    20/02/2026
# 31    25/02/2026
# Name: Date, dtype: object

# %%
df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(DATE_FORMAT)

# %%
df_pending
# Out:
#           Date  NaN                   Payee    Inflow   Outflow       NaN  \
# 0   10/12/2025  NaN     ביצוע הוראת קבע (י)       NaN    600.00   9451.53
# 1   10/12/2025  NaN       הרשאה ישראכרט (י)       NaN   2874.04       NaN
# 2   10/12/2025  NaN  מור גמל ופנסיה בע"מ(י)       NaN   1000.00   5577.49
# 3   11/12/2025  NaN        טן חברה לדלק (י)       NaN    481.84   5095.65
# 4   15/12/2025  NaN  הרשאה מקס איט פיננס(י)       NaN   7868.72  -2773.07
# 5   16/12/2025  NaN  זיכוי - בנק הפועלים(י)   3000.00       NaN    226.93
# 6   21/12/2025  NaN  ב. לאומי- קיצבת ילד(י)    112.00       NaN    338.93
# 7   01/01/2026  NaN              ריבית עו"ש     13.72       NaN    352.65
# 8   04/01/2026  NaN  זיכוי - בנק הפועלים(י)   3200.00       NaN       NaN
# 9   04/01/2026  NaN  זיכוי - בנק הפועלים(י)   5000.00       NaN   8552.65
# 10  11/01/2026  NaN     ביצוע הוראת קבע (י)       NaN    600.00       NaN
# 11  11/01/2026  NaN       הרשאה ישראכרט (י)       NaN   2504.63       NaN
# 12  11/01/2026  NaN        טן חברה לדלק (י)       NaN    476.61       NaN
# 13  11/01/2026  NaN  מור גמל ופנסיה בע"מ(י)       NaN    800.00   4171.41
# 14  12/01/2026  NaN  זיכוי - בנק הפועלים(י)   4990.00       NaN   9161.41
# 15  15/01/2026  NaN  הרשאה מקס איט פיננס(י)       NaN   5875.55   3285.86
# 16  20/01/2026  NaN  ב. לאומי- קיצבת ילד(י)    115.00       NaN   3400.86
# 17  01/02/2026  NaN  זיכוי - בנק הפועלים(י)   5000.00       NaN   8400.86
# 18  04/02/2026  NaN  זיכוי - בנק הפועלים(י)   5000.00       NaN  13400.86
# 19  06/02/2026  NaN  הרשאה מקס איט פיננס(י)       NaN     62.78  13338.08
# 20  08/02/2026  NaN  זיכוי - בנק הפועלים(י)  17000.00       NaN  30338.08
# 21  10/02/2026  NaN  ביטוח לאומי חד פעמי(י)  20315.00       NaN       NaN
# 22  10/02/2026  NaN     ביצוע הוראת קבע (י)       NaN    600.00       NaN
# 23  10/02/2026  NaN       הרשאה ישראכרט (י)       NaN   3427.00       NaN
# 24  10/02/2026  NaN  הרשאה מקס איט פיננס(י)       NaN    500.00       NaN
# 25  10/02/2026  NaN  מור גמל ופנסיה בע"מ(י)       NaN    800.00  45326.08
# 26  13/02/2026  NaN  ביטוח לאומי חד פעמי(י)    946.00       NaN       NaN
# 27  13/02/2026  NaN      העברה באינטרנט (י)       NaN   2000.00  44272.08
# 28  15/02/2026  NaN  הרשאה מקס איט פיננס(י)       NaN  12989.39       NaN
# 29  15/02/2026  NaN      העברה באינטרנט (י)       NaN   1400.00  29882.69
# 30  20/02/2026  NaN  ב. לאומי- קיצבת ילד(י)    115.00       NaN  29997.69
# 31  25/02/2026  NaN  ביטוח לאומי חד פעמי(י)    219.00       NaN  30216.69
#
#          NaN                      NaN  \
# 0         29  AccountActivity (1).xls
# 1      20543  AccountActivity (1).xls
# 2      57318  AccountActivity (1).xls
# 3      27839  AccountActivity (1).xls
# 4      34685  AccountActivity (1).xls
# 5      99012  AccountActivity (1).xls
# 6      13104  AccountActivity (1).xls
# 7   55555555  AccountActivity (1).xls
# 8      99012  AccountActivity (1).xls
# 9      99012  AccountActivity (1).xls
# 10        29  AccountActivity (1).xls
# 11     20543  AccountActivity (1).xls
# 12     27839  AccountActivity (1).xls
# 13     57318  AccountActivity (1).xls
# 14     99012  AccountActivity (1).xls
# 15     34685  AccountActivity (1).xls
# 16     13104  AccountActivity (1).xls
# 17     99012  AccountActivity (1).xls
# 18     99012  AccountActivity (1).xls
# 19     34685  AccountActivity (1).xls
# 20     99012  AccountActivity (1).xls
# 21     63051  AccountActivity (1).xls
# 22        29  AccountActivity (1).xls
# 23     20543  AccountActivity (1).xls
# 24     34685  AccountActivity (1).xls
# 25     57318  AccountActivity (1).xls
# 26     63051  AccountActivity (1).xls
# 27      6715  AccountActivity (1).xls
# 28     34685  AccountActivity (1).xls
# 29     25643  AccountActivity (1).xls
# 30     13104  AccountActivity (1).xls
# 31     63051  AccountActivity (1).xls
#
#                                                   NaN   NaN  \
# 0   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 1   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 2   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 3   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 4   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 5   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 6   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 7   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 8   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 9   C:\Users\shai\Documents\personal\personal_proj...  .xls
# 10  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 11  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 12  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 13  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 14  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 15  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 16  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 17  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 18  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 19  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 20  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 21  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 22  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 23  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 24  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 25  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 26  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 27  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 28  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 29  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 30  C:\Users\shai\Documents\personal\personal_proj...  .xls
# 31  C:\Users\shai\Documents\personal\personal_proj...  .xls
#
#                            NaN
# 0   mizrachi_read_html_table_1
# 1   mizrachi_read_html_table_1
# 2   mizrachi_read_html_table_1
# 3   mizrachi_read_html_table_1
# 4   mizrachi_read_html_table_1
# 5   mizrachi_read_html_table_1
# 6   mizrachi_read_html_table_1
# 7   mizrachi_read_html_table_1
# 8   mizrachi_read_html_table_1
# 9   mizrachi_read_html_table_1
# 10  mizrachi_read_html_table_1
# 11  mizrachi_read_html_table_1
# 12  mizrachi_read_html_table_1
# 13  mizrachi_read_html_table_1
# 14  mizrachi_read_html_table_1
# 15  mizrachi_read_html_table_1
# 16  mizrachi_read_html_table_1
# 17  mizrachi_read_html_table_1
# 18  mizrachi_read_html_table_1
# 19  mizrachi_read_html_table_1
# 20  mizrachi_read_html_table_1
# 21  mizrachi_read_html_table_1
# 22  mizrachi_read_html_table_1
# 23  mizrachi_read_html_table_1
# 24  mizrachi_read_html_table_1
# 25  mizrachi_read_html_table_1
# 26  mizrachi_read_html_table_1
# 27  mizrachi_read_html_table_1
# 28  mizrachi_read_html_table_1
# 29  mizrachi_read_html_table_1
# 30  mizrachi_read_html_table_1
# 31  mizrachi_read_html_table_1

# %%
df_pending = df_pending[GLOBAL_TRNASLATION_MAP.values()]

# %%
df_pending
# Out:
#           Date                   Payee    Inflow   Outflow
# 0   10/12/2025     ביצוע הוראת קבע (י)       NaN    600.00
# 1   10/12/2025       הרשאה ישראכרט (י)       NaN   2874.04
# 2   10/12/2025  מור גמל ופנסיה בע"מ(י)       NaN   1000.00
# 3   11/12/2025        טן חברה לדלק (י)       NaN    481.84
# 4   15/12/2025  הרשאה מקס איט פיננס(י)       NaN   7868.72
# 5   16/12/2025  זיכוי - בנק הפועלים(י)   3000.00       NaN
# 6   21/12/2025  ב. לאומי- קיצבת ילד(י)    112.00       NaN
# 7   01/01/2026              ריבית עו"ש     13.72       NaN
# 8   04/01/2026  זיכוי - בנק הפועלים(י)   3200.00       NaN
# 9   04/01/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 10  11/01/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 11  11/01/2026       הרשאה ישראכרט (י)       NaN   2504.63
# 12  11/01/2026        טן חברה לדלק (י)       NaN    476.61
# 13  11/01/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 14  12/01/2026  זיכוי - בנק הפועלים(י)   4990.00       NaN
# 15  15/01/2026  הרשאה מקס איט פיננס(י)       NaN   5875.55
# 16  20/01/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 17  01/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 18  04/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 19  06/02/2026  הרשאה מקס איט פיננס(י)       NaN     62.78
# 20  08/02/2026  זיכוי - בנק הפועלים(י)  17000.00       NaN
# 21  10/02/2026  ביטוח לאומי חד פעמי(י)  20315.00       NaN
# 22  10/02/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 23  10/02/2026       הרשאה ישראכרט (י)       NaN   3427.00
# 24  10/02/2026  הרשאה מקס איט פיננס(י)       NaN    500.00
# 25  10/02/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 26  13/02/2026  ביטוח לאומי חד פעמי(י)    946.00       NaN
# 27  13/02/2026      העברה באינטרנט (י)       NaN   2000.00
# 28  15/02/2026  הרשאה מקס איט פיננס(י)       NaN  12989.39
# 29  15/02/2026      העברה באינטרנט (י)       NaN   1400.00
# 30  20/02/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 31  25/02/2026  ביטוח לאומי חד פעמי(י)    219.00       NaN

# %%
df_pending = df_pending[[column for column in GLOBAL_TRNASLATION_MAP.values() if column in df_pending.columns]]

# %%
df_pending
# Out:
#           Date                   Payee    Inflow   Outflow
# 0   10/12/2025     ביצוע הוראת קבע (י)       NaN    600.00
# 1   10/12/2025       הרשאה ישראכרט (י)       NaN   2874.04
# 2   10/12/2025  מור גמל ופנסיה בע"מ(י)       NaN   1000.00
# 3   11/12/2025        טן חברה לדלק (י)       NaN    481.84
# 4   15/12/2025  הרשאה מקס איט פיננס(י)       NaN   7868.72
# 5   16/12/2025  זיכוי - בנק הפועלים(י)   3000.00       NaN
# 6   21/12/2025  ב. לאומי- קיצבת ילד(י)    112.00       NaN
# 7   01/01/2026              ריבית עו"ש     13.72       NaN
# 8   04/01/2026  זיכוי - בנק הפועלים(י)   3200.00       NaN
# 9   04/01/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 10  11/01/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 11  11/01/2026       הרשאה ישראכרט (י)       NaN   2504.63
# 12  11/01/2026        טן חברה לדלק (י)       NaN    476.61
# 13  11/01/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 14  12/01/2026  זיכוי - בנק הפועלים(י)   4990.00       NaN
# 15  15/01/2026  הרשאה מקס איט פיננס(י)       NaN   5875.55
# 16  20/01/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 17  01/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 18  04/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 19  06/02/2026  הרשאה מקס איט פיננס(י)       NaN     62.78
# 20  08/02/2026  זיכוי - בנק הפועלים(י)  17000.00       NaN
# 21  10/02/2026  ביטוח לאומי חד פעמי(י)  20315.00       NaN
# 22  10/02/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 23  10/02/2026       הרשאה ישראכרט (י)       NaN   3427.00
# 24  10/02/2026  הרשאה מקס איט פיננס(י)       NaN    500.00
# 25  10/02/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 26  13/02/2026  ביטוח לאומי חד פעמי(י)    946.00       NaN
# 27  13/02/2026      העברה באינטרנט (י)       NaN   2000.00
# 28  15/02/2026  הרשאה מקס איט פיננס(י)       NaN  12989.39
# 29  15/02/2026      העברה באינטרנט (י)       NaN   1400.00
# 30  20/02/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 31  25/02/2026  ביטוח לאומי חד פעמי(י)    219.00       NaN

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
import pandas as pd

# Canonical output date format for YNAB-bound data.
# Scope: shared project constant (belongs in a common constants module when stabilized).
YNAB_OUTPUT_DATE_FORMAT = "%d/%m/%Y"

# Accepted input date formats for Mizrachi exports.
# Scope: source-specific parser constant (belongs in Mizrachi parser module).
MIZRACHI_INPUT_DATE_FORMATS = ("%d/%m/%y", "%d/%m/%Y")

# Column translation from Hebrew source headers to canonical/intermediate names.
# Scope: keep source-specific until reused by multiple Hebrew sources.
HEBREW_TO_CANONICAL_COLUMN_MAP = {
    'תאריך': 'Date',
    'סוג תנועה': 'Payee',
    'זכות': 'Inflow',
    'חובה': 'Outflow'
}


def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


def parse_mizrachi_dates(
    raw_date_col: pd.Series, date_formats: tuple[str, ...] = MIZRACHI_INPUT_DATE_FORMATS
) -> pd.Series:
    # Clean raw values
    s = raw_date_col.astype(str).str.strip()
    s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})
    parsed = pd.to_datetime(s, format=date_formats[0], errors="coerce")
    # Second pass (only failed rows): dd/mm/yyyy
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_formats[0],
        errors="coerce",
    )
    return parsed


def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
    

    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_header_row_mizrachi_case(df_pending)

    df_pending = apply_detected_header(df_pending, header_row_idx)

    # find last footer of dataframe  using date column (non date values) or     
    # dataframe has been aligned to the header row

    # translating columns names using global mapping (for this project)
    df_pending.columns = df_pending.columns.map(HEBREW_TO_CANONICAL_COLUMN_MAP)
    
    # Align dates to dd/mm/YYYY format + drop rows with invalid dates
    parsed_dates = parse_mizrachi_dates(df_pending["Date"])
    # 2) Keep only valid date rows
    valid_mask = parsed_dates.notna()
    df_pending = df_pending.loc[valid_mask].copy()
    # 3) Format to dd/mm/yyyy
    df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(YNAB_OUTPUT_DATE_FORMAT)

    # Keep only the mapped columns if exist
    df_pending = df_pending[
        [column for column in HEBREW_TO_CANONICAL_COLUMN_MAP.values() if column in df_pending.columns]
    ]


    #  
# STEP: parse date
# STEP: split inflow/outflow
# TODO: handle installment rows


if __name__ == "__main__":
    path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
    dates_range = ("01/01/2026", "01/03/2026")
    main(path_to_folder=path_to_folder, dates_range=dates_range)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)

df_pending = apply_detected_header(df_pending, header_row_idx)

# find last footer of dataframe  using date column (non date values) or     
# dataframe has been aligned to the header row

# translating columns names using global mapping (for this project)
df_pending.columns = df_pending.columns.map(HEBREW_TO_CANONICAL_COLUMN_MAP)

# Align dates to dd/mm/YYYY format + drop rows with invalid dates
parsed_dates = parse_mizrachi_dates(df_pending["Date"])
# 2) Keep only valid date rows
valid_mask = parsed_dates.notna()
df_pending = df_pending.loc[valid_mask].copy()
# 3) Format to dd/mm/yyyy
df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(YNAB_OUTPUT_DATE_FORMAT)

# Keep only the mapped columns if exist
df_pending = df_pending[
    [column for column in HEBREW_TO_CANONICAL_COLUMN_MAP.values() if column in df_pending.columns]
]
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending
# Out:
#           Date                   Payee    Inflow   Outflow
# 0   10/12/2025     ביצוע הוראת קבע (י)       NaN    600.00
# 1   10/12/2025       הרשאה ישראכרט (י)       NaN   2874.04
# 2   10/12/2025  מור גמל ופנסיה בע"מ(י)       NaN   1000.00
# 3   11/12/2025        טן חברה לדלק (י)       NaN    481.84
# 4   15/12/2025  הרשאה מקס איט פיננס(י)       NaN   7868.72
# 5   16/12/2025  זיכוי - בנק הפועלים(י)   3000.00       NaN
# 6   21/12/2025  ב. לאומי- קיצבת ילד(י)    112.00       NaN
# 7   01/01/2026              ריבית עו"ש     13.72       NaN
# 8   04/01/2026  זיכוי - בנק הפועלים(י)   3200.00       NaN
# 9   04/01/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 10  11/01/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 11  11/01/2026       הרשאה ישראכרט (י)       NaN   2504.63
# 12  11/01/2026        טן חברה לדלק (י)       NaN    476.61
# 13  11/01/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 14  12/01/2026  זיכוי - בנק הפועלים(י)   4990.00       NaN
# 15  15/01/2026  הרשאה מקס איט פיננס(י)       NaN   5875.55
# 16  20/01/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 17  01/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 18  04/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 19  06/02/2026  הרשאה מקס איט פיננס(י)       NaN     62.78
# 20  08/02/2026  זיכוי - בנק הפועלים(י)  17000.00       NaN
# 21  10/02/2026  ביטוח לאומי חד פעמי(י)  20315.00       NaN
# 22  10/02/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 23  10/02/2026       הרשאה ישראכרט (י)       NaN   3427.00
# 24  10/02/2026  הרשאה מקס איט פיננס(י)       NaN    500.00
# 25  10/02/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 26  13/02/2026  ביטוח לאומי חד פעמי(י)    946.00       NaN
# 27  13/02/2026      העברה באינטרנט (י)       NaN   2000.00
# 28  15/02/2026  הרשאה מקס איט פיננס(י)       NaN  12989.39
# 29  15/02/2026      העברה באינטרנט (י)       NaN   1400.00
# 30  20/02/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 31  25/02/2026  ביטוח לאומי חד פעמי(י)    219.00       NaN

# %%
from etl_sources.mizrachi_reader import load_mizrachi_tables
from etl_sources.constants import YNAB_OUTPUT_DATE_FORMAT
from etl_sources.mizrachi_constants import (
    MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP,
    MIZRACHI_INPUT_DATE_FORMAT,
)
import pandas as pd


def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


def parse_mizrachi_dates(
    raw_date_col: pd.Series, date_format: str = MIZRACHI_INPUT_DATE_FORMAT
) -> pd.Series:
    # Clean raw values
    s = raw_date_col.astype(str).str.strip()
    s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})
    parsed = pd.to_datetime(s, format=date_format, errors="coerce")
    # Second pass (only failed rows): dd/mm/yyyy
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_format,
        errors="coerce",
    )
    return parsed


def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row

def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")
    

    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_header_row_mizrachi_case(df_pending)

    df_pending = apply_detected_header(df_pending, header_row_idx)

    # find last footer of dataframe  using date column (non date values) or     
    # dataframe has been aligned to the header row

    # translating columns names using global mapping (for this project)
    df_pending.columns = df_pending.columns.map(MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP)
    
    # Align dates to dd/mm/YYYY format + drop rows with invalid dates
    parsed_dates = parse_mizrachi_dates(df_pending["Date"])
    # 2) Keep only valid date rows
    valid_mask = parsed_dates.notna()
    df_pending = df_pending.loc[valid_mask].copy()
    # 3) Format to dd/mm/yyyy
    df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(YNAB_OUTPUT_DATE_FORMAT)

    # Keep only the mapped columns if exist
    df_pending = df_pending[
        [
            column
            for column in MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP.values()
            if column in df_pending.columns
        ]
    ]


    #  
# STEP: parse date
# STEP: split inflow/outflow
# TODO: handle installment rows


if __name__ == "__main__":
    path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
    dates_range = ("01/01/2026", "01/03/2026")
    main(path_to_folder=path_to_folder, dates_range=dates_range)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")


# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_header_row_mizrachi_case(df_pending)

df_pending = apply_detected_header(df_pending, header_row_idx)

# find last footer of dataframe  using date column (non date values) or     
# dataframe has been aligned to the header row

# translating columns names using global mapping (for this project)
df_pending.columns = df_pending.columns.map(MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP)

# Align dates to dd/mm/YYYY format + drop rows with invalid dates
parsed_dates = parse_mizrachi_dates(df_pending["Date"])
# 2) Keep only valid date rows
valid_mask = parsed_dates.notna()
df_pending = df_pending.loc[valid_mask].copy()
# 3) Format to dd/mm/yyyy
df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(YNAB_OUTPUT_DATE_FORMAT)

# Keep only the mapped columns if exist
df_pending = df_pending[
    [
        column
        for column in MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP.values()
        if column in df_pending.columns
    ]
]
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending
# Out:
#           Date                   Payee    Inflow   Outflow
# 0   10/12/2025     ביצוע הוראת קבע (י)       NaN    600.00
# 1   10/12/2025       הרשאה ישראכרט (י)       NaN   2874.04
# 2   10/12/2025  מור גמל ופנסיה בע"מ(י)       NaN   1000.00
# 3   11/12/2025        טן חברה לדלק (י)       NaN    481.84
# 4   15/12/2025  הרשאה מקס איט פיננס(י)       NaN   7868.72
# 5   16/12/2025  זיכוי - בנק הפועלים(י)   3000.00       NaN
# 6   21/12/2025  ב. לאומי- קיצבת ילד(י)    112.00       NaN
# 7   01/01/2026              ריבית עו"ש     13.72       NaN
# 8   04/01/2026  זיכוי - בנק הפועלים(י)   3200.00       NaN
# 9   04/01/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 10  11/01/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 11  11/01/2026       הרשאה ישראכרט (י)       NaN   2504.63
# 12  11/01/2026        טן חברה לדלק (י)       NaN    476.61
# 13  11/01/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 14  12/01/2026  זיכוי - בנק הפועלים(י)   4990.00       NaN
# 15  15/01/2026  הרשאה מקס איט פיננס(י)       NaN   5875.55
# 16  20/01/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 17  01/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 18  04/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 19  06/02/2026  הרשאה מקס איט פיננס(י)       NaN     62.78
# 20  08/02/2026  זיכוי - בנק הפועלים(י)  17000.00       NaN
# 21  10/02/2026  ביטוח לאומי חד פעמי(י)  20315.00       NaN
# 22  10/02/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 23  10/02/2026       הרשאה ישראכרט (י)       NaN   3427.00
# 24  10/02/2026  הרשאה מקס איט פיננס(י)       NaN    500.00
# 25  10/02/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 26  13/02/2026  ביטוח לאומי חד פעמי(י)    946.00       NaN
# 27  13/02/2026      העברה באינטרנט (י)       NaN   2000.00
# 28  15/02/2026  הרשאה מקס איט פיננס(י)       NaN  12989.39
# 29  15/02/2026      העברה באינטרנט (י)       NaN   1400.00
# 30  20/02/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 31  25/02/2026  ביטוח לאומי חד פעמי(י)    219.00       NaN

# %%
"""Prototype pipeline for normalizing Mizrachi exports toward YNAB shape."""

# Imports
from etl_sources.mizrachi_reader import load_mizrachi_tables
from etl_sources.constants import YNAB_OUTPUT_DATE_FORMAT
from etl_sources.mizrachi_constants import (
    MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP,
    MIZRACHI_INPUT_DATE_FORMAT,
)
import pandas as pd

# Orchestration
def main(path_to_folder: str, dates_range: tuple[str, str] | None = None) -> None:
    loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
    print(f"Loaded files: {len(loaded_tables)}")

    for table in loaded_tables:
        print(f"\nFile: {table.path.name} ({table.extension})")
        df_pending = table.dataframe
        print(df_pending.head())

    if dates_range:
        print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")

    # Detect header row in Mizrachi export via NaN-first-row signature.
    header_row_idx = detect_mizrachi_header_row(df_pending)

    df_pending = apply_detected_header(df_pending, header_row_idx)

    # find last footer of dataframe  using date column (non date values) or
    # dataframe has been aligned to the header row

    # translating columns names using global mapping (for this project)
    df_pending.columns = df_pending.columns.map(MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP)

    # Align dates to dd/mm/YYYY format + drop rows with invalid dates
    parsed_dates = parse_mizrachi_dates(df_pending["Date"])
    # 2) Keep only valid date rows
    valid_mask = parsed_dates.notna()
    df_pending = df_pending.loc[valid_mask].copy()
    # 3) Format to dd/mm/yyyy
    df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(YNAB_OUTPUT_DATE_FORMAT)

    # Keep only the mapped columns if exist
    df_pending = df_pending[
        [
            column
            for column in MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP.values()
            if column in df_pending.columns
        ]
    ]

    # Prototype next steps:
    # - Split inflow/outflow to YNAB-compatible amount fields.
    # - Add installment-specific handling.

# Pipeline steps
# Header detection
def detect_mizrachi_header_row(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """
    Heuristic:
    1) Find first column that has NaN in the first `probe_rows`.
    2) In that column, return first non-null row index.
    3) If no signal found, return default_row.
    """
    if df.empty:
        return default_row
    # Step 1: columns that look like your Mizrachi signature
    candidate_cols = [
        col for col in df.columns
        if df[col].iloc[:probe_rows].isna().any()
    ]
    # Step 2: find first non-null row in first matching column
    for col in candidate_cols:
        first_valid = df[col].first_valid_index()  # returns None if all null
        if first_valid is not None:
            return int(first_valid)
    return default_row


def detect_header_row_mizrachi_case(
    df: pd.DataFrame,
    default_row: int = 3,
    probe_rows: int = 1,
) -> int:
    """Backward-compatible alias for detect_mizrachi_header_row."""
    return detect_mizrachi_header_row(df, default_row=default_row, probe_rows=probe_rows)


# Header application
def apply_detected_header(df: pd.DataFrame, header_row_idx: int) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    if header_row_idx < 0 or header_row_idx >= len(df):
        raise ValueError(
            f"Detected header_row_idx {header_row_idx} is out of bounds for dataframe with {len(df)} rows."
        )

    raw_header = df.iloc[header_row_idx, :]
    cleaned_header = []
    for col_idx, value in enumerate(raw_header):
        if pd.isna(value):
            cleaned_header.append(f"unnamed_{col_idx}")
            continue

        header_name = str(value).strip()
        cleaned_header.append(header_name or f"unnamed_{col_idx}")

    normalized_columns = _dedupe_column_names(cleaned_header)
    normalized_df = df.iloc[header_row_idx + 1 :].copy().reset_index(drop=True)
    normalized_df.columns = normalized_columns
    return normalized_df


# Date parsing
def parse_mizrachi_dates(
    raw_date_col: pd.Series, date_format: str = MIZRACHI_INPUT_DATE_FORMAT
) -> pd.Series:
    # Clean raw values
    s = raw_date_col.astype(str).str.strip()
    s = s.replace({"": pd.NA, "nan": pd.NA, "None": pd.NA})
    parsed = pd.to_datetime(s, format=date_format, errors="coerce")
    # Second pass (only failed rows): dd/mm/yyyy
    missing = parsed.isna()
    parsed.loc[missing] = pd.to_datetime(
        s.loc[missing],
        format=date_format,
        errors="coerce",
    )
    return parsed

# Helpers
def _dedupe_column_names(names: list[str]) -> list[str]:
    seen_counts: dict[str, int] = {}
    deduped: list[str] = []

    for name in names:
        count = seen_counts.get(name, 0) + 1
        seen_counts[name] = count
        deduped.append(name if count == 1 else f"{name}_{count}")

    return deduped


# Entry point
if __name__ == "__main__":
    path_to_folder = r'C:\Users\shai\Documents\personal\personal_projects\ynab-israel-consolidator\private_data\incoming\bank_mizrachi'
    dates_range = ("01/01/2026", "01/03/2026")
    main(path_to_folder=path_to_folder, dates_range=dates_range)
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
loaded_tables = load_mizrachi_tables(folder=path_to_folder, recursive=False)
print(f"Loaded files: {len(loaded_tables)}")

for table in loaded_tables:
    print(f"\nFile: {table.path.name} ({table.extension})")
    df_pending = table.dataframe
    print(df_pending.head())

if dates_range:
    print(f"Requested date range: {dates_range[0]} -> {dates_range[1]}")

# Detect header row in Mizrachi export via NaN-first-row signature.
header_row_idx = detect_mizrachi_header_row(df_pending)

df_pending = apply_detected_header(df_pending, header_row_idx)

# find last footer of dataframe  using date column (non date values) or
# dataframe has been aligned to the header row

# translating columns names using global mapping (for this project)
df_pending.columns = df_pending.columns.map(MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP)

# Align dates to dd/mm/YYYY format + drop rows with invalid dates
parsed_dates = parse_mizrachi_dates(df_pending["Date"])
# 2) Keep only valid date rows
valid_mask = parsed_dates.notna()
df_pending = df_pending.loc[valid_mask].copy()
# 3) Format to dd/mm/yyyy
df_pending["Date"] = parsed_dates.loc[valid_mask].dt.strftime(YNAB_OUTPUT_DATE_FORMAT)

# Keep only the mapped columns if exist
df_pending = df_pending[
    [
        column
        for column in MIZRACHI_HEBREW_TO_CANONICAL_COLUMN_MAP.values()
        if column in df_pending.columns
    ]
]
# Out:
# Loaded files: 1
#
# File: AccountActivity (1).xls (.xls)
#                 0          1                    2               3       4  \
# 0    יתרה בחשבון:   29856.69             לתאריך -  05/03/26 23:15     NaN
# 1    מסגרת אשראי:   20000.00                  NaN             NaN     NaN
# 2  תנועות אחרונות        NaN                  NaN             NaN     NaN
# 3           תאריך  תאריך ערך            סוג תנועה            זכות    חובה
# 4        10/12/25        NaN  ביצוע הוראת קבע (י)             NaN  600.00
#
#            5       6            __source_file  \
# 0        NaN     NaN  AccountActivity (1).xls
# 1        NaN     NaN  AccountActivity (1).xls
# 2        NaN     NaN  AccountActivity (1).xls
# 3  יתרה בש"ח  אסמכתא  AccountActivity (1).xls
# 4    9451.53      29  AccountActivity (1).xls
#
#                                        __source_path __source_ext  \
# 0  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 1  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 2  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 3  C:\Users\shai\Documents\personal\personal_proj...         .xls
# 4  C:\Users\shai\Documents\personal\personal_proj...         .xls
#
#                 __source_rule
# 0  mizrachi_read_html_table_1
# 1  mizrachi_read_html_table_1
# 2  mizrachi_read_html_table_1
# 3  mizrachi_read_html_table_1
# 4  mizrachi_read_html_table_1
# Requested date range: 01/01/2026 -> 01/03/2026

# %%
df_pending
# Out:
#           Date                   Payee    Inflow   Outflow
# 0   10/12/2025     ביצוע הוראת קבע (י)       NaN    600.00
# 1   10/12/2025       הרשאה ישראכרט (י)       NaN   2874.04
# 2   10/12/2025  מור גמל ופנסיה בע"מ(י)       NaN   1000.00
# 3   11/12/2025        טן חברה לדלק (י)       NaN    481.84
# 4   15/12/2025  הרשאה מקס איט פיננס(י)       NaN   7868.72
# 5   16/12/2025  זיכוי - בנק הפועלים(י)   3000.00       NaN
# 6   21/12/2025  ב. לאומי- קיצבת ילד(י)    112.00       NaN
# 7   01/01/2026              ריבית עו"ש     13.72       NaN
# 8   04/01/2026  זיכוי - בנק הפועלים(י)   3200.00       NaN
# 9   04/01/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 10  11/01/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 11  11/01/2026       הרשאה ישראכרט (י)       NaN   2504.63
# 12  11/01/2026        טן חברה לדלק (י)       NaN    476.61
# 13  11/01/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 14  12/01/2026  זיכוי - בנק הפועלים(י)   4990.00       NaN
# 15  15/01/2026  הרשאה מקס איט פיננס(י)       NaN   5875.55
# 16  20/01/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 17  01/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 18  04/02/2026  זיכוי - בנק הפועלים(י)   5000.00       NaN
# 19  06/02/2026  הרשאה מקס איט פיננס(י)       NaN     62.78
# 20  08/02/2026  זיכוי - בנק הפועלים(י)  17000.00       NaN
# 21  10/02/2026  ביטוח לאומי חד פעמי(י)  20315.00       NaN
# 22  10/02/2026     ביצוע הוראת קבע (י)       NaN    600.00
# 23  10/02/2026       הרשאה ישראכרט (י)       NaN   3427.00
# 24  10/02/2026  הרשאה מקס איט פיננס(י)       NaN    500.00
# 25  10/02/2026  מור גמל ופנסיה בע"מ(י)       NaN    800.00
# 26  13/02/2026  ביטוח לאומי חד פעמי(י)    946.00       NaN
# 27  13/02/2026      העברה באינטרנט (י)       NaN   2000.00
# 28  15/02/2026  הרשאה מקס איט פיננס(י)       NaN  12989.39
# 29  15/02/2026      העברה באינטרנט (י)       NaN   1400.00
# 30  20/02/2026  ב. לאומי- קיצבת ילד(י)    115.00       NaN
# 31  25/02/2026  ביטוח לאומי חד פעמי(י)    219.00       NaN
